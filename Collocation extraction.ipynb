# %% [markdown]
# Import all the libraries we need

# %%
import gensim
import logging
import numpy as np
import re
from conllu import parse
import os
from sympy import Point, Line, Segment
from scipy.spatial import distance
from pymorphy2 import MorphAnalyzer
from nltk.tokenize import sent_tokenize, wordpunct_tokenize, word_tokenize
from nltk.collocations import BigramCollocationFinder, BigramAssocMeasures
from nltk.corpus import stopwords

import warnings
warnings.filterwarnings('ignore')

# %%
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %%
path = os.getcwd()
conllu_file = path + '/UD_Russian-SynTagRus/ru_syntagrus-ud-train.conllu'

# %% [markdown]
# Parse the CoNLL-U file

# %%
with open(conllu_file, "r", encoding="utf-8") as data_file:
    data = data_file.read()
sentences = parse(data)

# %% [markdown]
# Lemmatize texts and put part-of-speech tags for each word in them

# %%
with open('result.txt', 'w', encoding='utf-8') as result:
    for sentence in sentences:
        line = ' '.join([word['lemma'] + '_' + word['upos'] for word in sentence if word['upos'] != 'PUNCT' and word['upos'] != 'NUM'])
        result.write(line + '\n')

# %%
f = 'result.txt'
data = gensim.models.word2vec.LineSentence(f)

# %% [markdown]
# Compile a dictionary only from words longer than two characters and not included in the list of stop words for the Russian language

# %%
stops = set(stopwords.words('russian'))
words = [word['lemma'] + '_' + word['upos'] for sentence in sentences for word in sentence
         if len(word) > 2
         and word['lemma'] not in stops]

# %% [markdown]
# Calculate the association measure for each bigram obtained from the texts

# %%
finder = BigramCollocationFinder.from_words(words)
bgm = BigramAssocMeasures()
score = bgm.mi_like
collocations = {' '.join(bigram): pmi for bigram, pmi in finder.score_ngrams(score)}

# %% [markdown]
# Leave only phrases consisting of an adjective and a noun

# %%
colloc = [key for key, value in collocations.items() if value > 1 and re.match(r'[а-я]+_ADJ [а-я]+_NOUN', key)]

# %% [markdown]
# In the collocations highlighted by the MI measure, we connect the words with an underscore so that the model perceives them as a single whole

# %%
# %time
with open('result.txt', 'r', encoding='utf-8') as file:
    text = file.read()
for c in colloc:
    repl = c.replace(' ', '_')
    text = text.replace(c, repl)
with open('result_new.txt', 'w', encoding='utf-8') as result:
    result.write(text)

# %% [markdown]
# Train the Word2Vec model

# %%
# %time model = gensim.models.Word2Vec(data, vector_size=300, window=5, min_count=5, epochs=50)

# %%
model.save('w2v.model')

# %%
model = gensim.models.Word2Vec.load('w2v.model')

# %% [markdown]
# Create a function that calculates the mean vector for two words in a phrase

# %%
def get_mean_vector(word2vec_model, words):
    vectors = [model.wv.get_vector(word, norm=True) for word in words if word in word2vec_model.wv]
    if len(words) >= 1:
        return gensim.matutils.unitvec(np.mean(vectors, axis=0)).astype(float)
    else:
        return []

# %% [markdown]
# Calculate for each phrase the distance from the midpoint to the line connecting the words, and sort the phrases in descending order of the calculated distance

# %%
ud_collocations = {}
for c in colloc:
    adj, noun = c.split()
    if adj in model.wv and noun in model.wv:
        p1, p2, p3 = Point(model.wv[adj], evaluate=False), Point(model.wv[noun], evaluate=False), Point(get_mean_vector(model, [adj, noun]), evaluate=False)
        l1 = Line(p1, p2)
        dist = distance.euclidean(np.array(p3).astype(float), np.array(l1.projection(p3)).astype(float))
        ud_collocations[c] = dist

# %%
ud_collocations = {i: ud_collocations[i] for i in sorted(ud_collocations, key=ud_collocations.get, reverse=True)}
ud_collocations
# Out:
# {'самый_ADJ дело_NOUN': 15.158156330852007,
#  'экономический_ADJ рост_NOUN': 14.33828849291259,
#  'русский_ADJ язык_NOUN': 14.111519883686263,
#  'первый_ADJ очередь_NOUN': 12.957828971144938,
#  'больший_ADJ часть_NOUN': 12.938151326550942,
#  'ядерный_ADJ оружие_NOUN': 12.764024274189852,
#  'значительный_ADJ часть_NOUN': 12.443441886875654,
#  'высший_ADJ образование_NOUN': 12.361910296405629,
#  'высший_ADJ школа_NOUN': 11.809780359480094,
#  'средний_ADJ класс_NOUN': 11.703104855735296,
#  'настоящий_ADJ время_NOUN': 11.555916390021013,
#  'прошлый_ADJ год_NOUN': 11.515941841794097,
#  'пенсионный_ADJ возраст_NOUN': 9.637137339877176,
#  'железный_ADJ дорога_NOUN': 9.386149038196775,
#  'конечный_ADJ счет_NOUN': 9.36536199876118,
#  'головной_ADJ мозг_NOUN': 8.90222203926927,
#  'крайний_ADJ мера_NOUN': 8.843125443730608,
#  'жидкий_ADJ мембрана_NOUN': 8.348501462723748,
#  'золотой_ADJ медаль_NOUN': 7.773153748232594,
#  'розничный_ADJ сеть_NOUN': 7.588308673844453,
#  'сельский_ADJ хозяйство_NOUN': 7.514950792993694,
#  'местный_ADJ самоуправление_NOUN': 6.981710515755966,
#  'черный_ADJ дыра_NOUN': 6.940884475080358,
#  'программный_ADJ обеспечение_NOUN': 6.884518406052239,
#  'квадратный_ADJ метр_NOUN': 6.689094005730448,
#  'мобильный_ADJ телефон_NOUN': 6.666494077930874,
#  'маленький_ADJ принц_NOUN': 5.25407522967783,
#  'учебный_ADJ заведение_NOUN': 5.18699533415753,
#  'правоохранительный_ADJ орган_NOUN': 5.154408216399399,
#  'офисный_ADJ мебель_NOUN': 4.779691258464387,
#  'подводный_ADJ лодка_NOUN': 4.4292869593196835,
#  'фондовый_ADJ рынок_NOUN': 4.047089468907754,
#  'нобелевский_ADJ лауреат_NOUN': 3.711737835454563,
#  'кристаллический_ADJ решетка_NOUN': 3.6991054942328865,
#  'кандидатский_ADJ диссертация_NOUN': 3.509194179086052,
#  'смертный_ADJ казнь_NOUN': 3.129433394227617,
#  'радикальный_ADJ феминистка_NOUN': 2.352943910100869,
#  'стихийный_ADJ бедствие_NOUN': 2.204043696651453}

# %% [markdown]
# Let's repeat these steps for texts in chemistry

# %%
morph = MorphAnalyzer()

# %%
def pos(word):
    return morph.parse(word)[0].tag.POS

func_pos = {'INTJ', 'PRCL', 'CONJ', 'PREP', 'NPRO', 'NUMR', None}

# %%
with open('all_cyberleninka_chemystry2.txt', "r", encoding="utf-8") as txt_file:
    texts = txt_file.read()

# %%
s_tokenized = sent_tokenize(texts)

# %%
tokens = [[token for token in wordpunct_tokenize(s)
           if pos(token) not in func_pos and token not in stops]
          for s in s_tokenized]

# %%
with open('chemistry.txt', 'w', encoding='utf-8') as file:
    for s in tokens:
        if s:
            s_lemmatized = ' '.join([morph.parse(token)[0].normal_form + '_' + pos(token) for token in s
                                     if str(morph.parse(token)[0].tag) != 'PNCT'])
            file.write(s_lemmatized + '\n')

# %%
f = 'chemistry.txt'
data = gensim.models.word2vec.LineSentence(f)

# %%
lines = [line.strip() for line in open(f, encoding='utf-8')]

# %%
words = [word for line in lines for word in line.split()]

# %%
finder = BigramCollocationFinder.from_words(words)
bgm = BigramAssocMeasures()
score = bgm.mi_like
collocations = {' '.join(bigram): pmi for bigram, pmi in finder.score_ngrams(score)}

# %%
colloc = [key for key, value in collocations.items() if value > 1 and re.match(r'[а-я]+_ADJF [а-я]+_NOUN', key)]

# %%
with open('chemistry.txt', 'r', encoding='utf-8') as file:
    text = file.read()
for c in colloc:
    repl = c.replace(' ', '_')
    text = text.replace(c, repl)
with open('chemistry_new.txt', 'w', encoding='utf-8') as result:
    result.write(text)

# %%
# %time model = gensim.models.Word2Vec(data, vector_size=300, window=5, min_count=5, epochs=50)

# %%
model.save('w2v_chem.model')

# %%
model = gensim.models.Word2Vec.load('w2v_chem.model')

# %%
c_dict = {}
for c in colloc:
    adj, noun = c.split()
    if adj in model.wv and noun in model.wv:
        p1, p2, p3 = Point(model.wv[adj], evaluate=False), Point(model.wv[noun], evaluate=False), Point(get_mean_vector(model, [adj, noun]), evaluate=False)
        l1 = Line(p1, p2)
        dist = distance.euclidean(np.array(p3).astype(float), np.array(l1.projection(p3)).astype(float))
        c_dict[c] = dist

# %%
sorted_colls = {i: c_dict[i] for i in sorted(c_dict, key=c_dict.get, reverse=True)}
sorted_colls
# Out:
# {'государственный_ADJF университет_NOUN': 24.750774255764522,
#  'прочностный_ADJF свойство_NOUN': 24.08047151042016,
#  'амперометрический_ADJF биосенсор_NOUN': 23.70061566999836,
#  'адгезионный_ADJF прочность_NOUN': 23.671127700865718,
#  'компьютерный_ADJF программа_NOUN': 23.656466316097184,
#  'реологический_ADJF свойство_NOUN': 23.435833916397655,
#  'актуальный_ADJF проблема_NOUN': 23.336830819606657,
#  'ковалентный_ADJF связь_NOUN': 23.258859150862737,
#  'нуклеофильный_ADJF атака_NOUN': 23.255462267856043,
#  'инверсионный_ADJF вольтамперометрия_NOUN': 23.13523353557722,
#  'рентгеновский_ADJF дифрактометр_NOUN': 23.092514801804764,
#  'важный_ADJF задача_NOUN': 23.087013445579146,
#  'исследовательский_ADJF институт_NOUN': 23.08655971799994,
#  'экологический_ADJF безопасность_NOUN': 23.058169668008862,
#  'актуальный_ADJF задача_NOUN': 23.02834005709894,
#  'надмолекулярный_ADJF структура_NOUN': 23.01560913530108,
#  'мировой_ADJF рынок_NOUN': 23.00483674354127,
#  'научный_ADJF школа_NOUN': 22.86030681023408,
#  'защитный_ADJF покрытие_NOUN': 22.85515221098746,
#  'коррозионный_ADJF стойкость_NOUN': 22.76291829665459,
#  'антиоксидантный_ADJF активность_NOUN': 22.722176028925826,
#  'молярный_ADJF коэффициент_NOUN': 22.703731129994885,
#  'федеральный_ADJF университет_NOUN': 22.679140679400856,
#  'электростатический_ADJF отталкивание_NOUN': 22.592366090484024,
#  'программный_ADJF пакет_NOUN': 22.59173385755614,
#  'механический_ADJF свойство_NOUN': 22.572997908307713,
#  'коррозионный_ADJF испытание_NOUN': 22.517275464425087,
#  'международный_ADJF конференция_NOUN': 22.41929037733655,
#  'потенциометрический_ADJF титрование_NOUN': 22.350448640369816,
#  'анодный_ADJF растворение_NOUN': 22.224476555737343,
#  'кинетический_ADJF уравнение_NOUN': 22.208299692391986,
#  'коллоидный_ADJF частица_NOUN': 22.17727978550593,
#  'побочный_ADJF продукт_NOUN': 22.176645801379838,
#  'питьевой_ADJF водоснабжение_NOUN': 22.176117940470757,
#  'всероссийский_ADJF конференция_NOUN': 22.139723487970222,
#  'практический_ADJF интерес_NOUN': 22.127881690343532,
#  'межфазный_ADJF граница_NOUN': 22.118782868876657,
#  'пищевой_ADJF промышленность_NOUN': 22.11851155689595,
#  'сорбционный_ADJF способность_NOUN': 22.105553481470704,
#  'карбоксильный_ADJF группа_NOUN': 22.102700675809665,
#  'радикальный_ADJF полимеризация_NOUN': 22.097491032702525,
#  'ультразвуковой_ADJF обработка_NOUN': 22.090283034211375,
#  'высокий_ADJF значение_NOUN': 22.052111187003433,
#  'экологический_ADJF проблема_NOUN': 22.043240124837368,
#  'стерический_ADJF затруднение_NOUN': 22.04216897785456,
#  'математический_ADJF модель_NOUN': 22.034002892887454,
#  'сорбционный_ADJF свойство_NOUN': 22.02516593430129,
#  'резкий_ADJF увеличение_NOUN': 22.019338428266785,
#  'радикальный_ADJF распад_NOUN': 21.981293626911636,
#  'стационарный_ADJF потенциал_NOUN': 21.968296994210323,
#  'катодный_ADJF поляризация_NOUN': 21.94058388646906,
#  'керамический_ADJF материал_NOUN': 21.937936467447102,
#  'политермический_ADJF разрез_NOUN': 21.935545971456943,
#  'алкильный_ADJF заместитель_NOUN': 21.931675374683806,
#  'анодный_ADJF пик_NOUN': 21.92413842566299,
#  'оптимальный_ADJF условие_NOUN': 21.879978081843145,
#  'высокий_ADJF степень_NOUN': 21.872058800686364,
#  'уксусный_ADJF кислота_NOUN': 21.863012923187988,
#  'высокий_ADJF чистота_NOUN': 21.85031427890548,
#  'лазерный_ADJF излучение_NOUN': 21.845476086788118,
#  'важный_ADJF роль_NOUN': 21.84525792482171,
#  'спиновый_ADJF релаксация_NOUN': 21.843142184685927,
#  'механический_ADJF прочность_NOUN': 21.83022831053682,
#  'программный_ADJF обеспечение_NOUN': 21.81087449552608,
#  'боковой_ADJF цепь_NOUN': 21.751094392037864,
#  'рентгеновский_ADJF дифракция_NOUN': 21.73326855994625,
#  'сдвиговый_ADJF деформация_NOUN': 21.71335125900049,
#  'нонвариантный_ADJF точка_NOUN': 21.678648204123142,
#  'химический_ADJF свойство_NOUN': 21.668928065589537,
#  'платиновый_ADJF электрод_NOUN': 21.64278223296463,
#  'карбонильный_ADJF группа_NOUN': 21.640444587265073,
#  'анодный_ADJF зубец_NOUN': 21.638175137882385,
#  'пищевой_ADJF технология_NOUN': 21.626755276461004,
#  'хроматографический_ADJF колонка_NOUN': 21.620008420335168,
#  'прочностный_ADJF характеристика_NOUN': 21.61485071560374,
#  'промышленный_ADJF производство_NOUN': 21.600820099168807,
#  'больший_ADJF значение_NOUN': 21.596764735706365,
#  'фотометрический_ADJF определение_NOUN': 21.575444153052935,
#  'анодный_ADJF поляризация_NOUN': 21.571965862447787,
#  'резкий_ADJF снижение_NOUN': 21.550726442181173,
#  'нуклеофильный_ADJF замещение_NOUN': 21.549872919195593,
#  'максимальный_ADJF значение_NOUN': 21.528727341368786,
#  'алюминиевый_ADJF сплав_NOUN': 21.50096639419474,
#  'лекарственный_ADJF препарат_NOUN': 21.50080336646382,
#  'лекарственный_ADJF средство_NOUN': 21.462642285912178,
#  'электродный_ADJF потенциал_NOUN': 21.457261884490546,
#  'вольтамперный_ADJF кривая_NOUN': 21.416210812127865,
#  'химический_ADJF факультет_NOUN': 21.413269250979784,
#  'поверхностный_ADJF слой_NOUN': 21.383356166696416,
#  'математический_ADJF описание_NOUN': 21.380192865742455,
#  'прикладной_ADJF химия_NOUN': 21.376430883277216,
#  'взрывчатый_ADJF вещество_NOUN': 21.359004120430054,
#  'электрический_ADJF ток_NOUN': 21.35639283585627,
#  'больший_ADJF степень_NOUN': 21.346322162759694,
#  'электромагнитный_ADJF излучение_NOUN': 21.338339776091868,
#  'высокий_ADJF содержание_NOUN': 21.320925954780844,
#  'алкильный_ADJF радикал_NOUN': 21.30414710471873,
#  'колебательный_ADJF спектр_NOUN': 21.295660483734235,
#  'электрофильный_ADJF замещение_NOUN': 21.283519859651125,
#  'поляризационный_ADJF кривая_NOUN': 21.26209186740065,
#  'защитный_ADJF свойство_NOUN': 21.2589376035549,
#  'высокий_ADJF стоимость_NOUN': 21.24284425434737,
#  'валентный_ADJF колебание_NOUN': 21.225320023317238,
#  'горючий_ADJF сланец_NOUN': 21.194210811234246,
#  'математический_ADJF моделирование_NOUN': 21.193148007677067,
#  'хроматографический_ADJF анализ_NOUN': 21.18992701762443,
#  'фазовый_ADJF диаграмма_NOUN': 21.18179809776228,
#  'метрический_ADJF титрование_NOUN': 21.1553319286643,
#  'переменный_ADJF ток_NOUN': 21.1438738594221,
#  'электростатический_ADJF взаимодействие_NOUN': 21.13357247845417,
#  'высокий_ADJF разрешение_NOUN': 21.126275686310034,
#  'гетероциклический_ADJF соединение_NOUN': 21.121109184558463,
#  'индикаторный_ADJF электрод_NOUN': 21.102695417107697,
#  'лакокрасочный_ADJF покрытие_NOUN': 21.09376189898864,
#  'электрический_ADJF сопротивление_NOUN': 21.08124580938161,
#  'буферный_ADJF раствор_NOUN': 21.067190817327653,
#  'тафелевский_ADJF наклон_NOUN': 21.057264859275534,
#  'педагогический_ADJF университет_NOUN': 21.054688192782702,
#  'разрывный_ADJF машина_NOUN': 21.021845775422655,
#  'низкий_ADJF значение_NOUN': 21.02113604807209,
#  'целлюлозный_ADJF волокно_NOUN': 20.985721591985488,
#  'инженерный_ADJF экология_NOUN': 20.972357689444447,
#  'живой_ADJF организм_NOUN': 20.933182911809624,
#  'косметический_ADJF средство_NOUN': 20.930745174324947,
#  'координационный_ADJF полиэдр_NOUN': 20.92653550686768,
#  'эксплуатационный_ADJF свойство_NOUN': 20.921371094634413,
#  'магнитный_ADJF восприимчивость_NOUN': 20.920328323355193,
#  'строительный_ADJF материал_NOUN': 20.917816284523226,
#  'высокий_ADJF школа_NOUN': 20.89375580305768,
#  'технологический_ADJF факультет_NOUN': 20.89280202660387,
#  'рентгеновский_ADJF дифрактограмма_NOUN': 20.883325530815725,
#  'кристаллический_ADJF структура_NOUN': 20.861442229181783,
#  'сернистый_ADJF газ_NOUN': 20.853082896688743,
#  'сверхкритический_ADJF диоксид_NOUN': 20.851151600721376,
#  'диэлектрический_ADJF проницаемость_NOUN': 20.83179488430328,
#  'электронный_ADJF спектр_NOUN': 20.823418272393663,
#  'фрактальный_ADJF размерность_NOUN': 20.814537177468118,
#  'логарифмический_ADJF координата_NOUN': 20.807667008990933,
#  'микроволновый_ADJF излучение_NOUN': 20.79967558623174,
#  'радиоактивный_ADJF отход_NOUN': 20.784134227839605,
#  'конструкционный_ADJF материал_NOUN': 20.76572496256844,
#  'координационный_ADJF соединение_NOUN': 20.751965479692497,
#  'кадмиевый_ADJF аккумулятор_NOUN': 20.75187516668785,
#  'пространственный_ADJF сетка_NOUN': 20.733017033869476,
#  'насыпной_ADJF плотность_NOUN': 20.73192874208745,
#  'промышленный_ADJF предприятие_NOUN': 20.72620095693422,
#  'композиционный_ADJF материал_NOUN': 20.72037237218194,
#  'фоновый_ADJF электролит_NOUN': 20.711860318476457,
#  'молярный_ADJF соотношение_NOUN': 20.709270793420398,
#  'вакантный_ADJF орбиталь_NOUN': 20.707254887834182,
#  'температурный_ADJF режим_NOUN': 20.69616740631939,
#  'золотосодержащий_ADJF руда_NOUN': 20.69214340518315,
#  'графитовый_ADJF электрод_NOUN': 20.684662839257808,
#  'парафиновый_ADJF углеводород_NOUN': 20.67878874286759,
#  'фенильный_ADJF кольцо_NOUN': 20.65718609024613,
#  'внутримолекулярный_ADJF циклизация_NOUN': 20.627365191462996,
#  'деформационный_ADJF колебание_NOUN': 20.626337460721423,
#  'сульфидный_ADJF руда_NOUN': 20.604996145482637,
#  'стерический_ADJF препятствие_NOUN': 20.60466455958999,
#  'интенсивный_ADJF полоса_NOUN': 20.60128299587013,
#  'бензойный_ADJF кислота_NOUN': 20.590765927547643,
#  'гальванический_ADJF производство_NOUN': 20.58597727737906,
#  'изотопный_ADJF обмен_NOUN': 20.580972790800086,
#  'химический_ADJF технология_NOUN': 20.57287531282843,
#  'температурный_ADJF зависимость_NOUN': 20.57111974014494,
#  'никелевый_ADJF покрытие_NOUN': 20.569329277682662,
#  'питьевой_ADJF вода_NOUN': 20.560185359306814,
#  'углеродный_ADJF атом_NOUN': 20.55579113504882,
#  'пластический_ADJF деформация_NOUN': 20.55347902006566,
#  'особый_ADJF интерес_NOUN': 20.546181102389173,
#  'агрессивный_ADJF среда_NOUN': 20.54346938430723,
#  'медиаторный_ADJF биосенсор_NOUN': 20.537895720629226,
#  'парциальный_ADJF давление_NOUN': 20.53684670757384,
#  'таутомерный_ADJF форма_NOUN': 20.5345051986113,
#  'образовательный_ADJF учреждение_NOUN': 20.532299505167156,
#  'кварцевый_ADJF кювет_NOUN': 20.522543731409932,
#  'рентгенофазовый_ADJF анализ_NOUN': 20.520754301689326,
#  'текстильный_ADJF материал_NOUN': 20.512369984525996,
#  'существенный_ADJF влияние_NOUN': 20.50852453110045,
#  'лабораторный_ADJF установка_NOUN': 20.498824016091007,
#  'углеродный_ADJF материал_NOUN': 20.491310054666553,
#  'капиллярный_ADJF колонка_NOUN': 20.48855457159661,
#  'глинистый_ADJF минерал_NOUN': 20.48701595248631,
#  'хлопковый_ADJF целлюлоза_NOUN': 20.481819151020385,
#  'ионный_ADJF проводимость_NOUN': 20.466865664220613,
#  'термодинамический_ADJF параметр_NOUN': 20.455203010139417,
#  'спектрофотометрический_ADJF метод_NOUN': 20.45424207081584,
#  'энергетический_ADJF барьер_NOUN': 20.45369609539726,
#  'моноклинный_ADJF сингония_NOUN': 20.442573012920885,
#  'широкий_ADJF спектр_NOUN': 20.432810318651935,
#  'метиленовый_ADJF группа_NOUN': 20.428584868732408,
#  'восстановительный_ADJF потенциал_NOUN': 20.415056898595857,
#  'фотометрический_ADJF метод_NOUN': 20.40311447432448,
#  'амальгамный_ADJF полярография_NOUN': 20.402092544766575,
#  'мономерный_ADJF звено_NOUN': 20.390207857236632,
#  'окислительный_ADJF деструкция_NOUN': 20.388937880006818,
#  'технологический_ADJF институт_NOUN': 20.37985831407679,
#  'электронный_ADJF строение_NOUN': 20.37503493472729,
#  'моющий_ADJF средство_NOUN': 20.3706000467652,
#  'структурный_ADJF фрагмент_NOUN': 20.369606533141553,
#  'газообразный_ADJF продукт_NOUN': 20.365762851007787,
#  'российский_ADJF академия_NOUN': 20.364196359654244,
#  'компьютерный_ADJF моделирование_NOUN': 20.359407438445523,
#  'наноразмерный_ADJF частица_NOUN': 20.352300175565166,
#  'минеральный_ADJF удобрение_NOUN': 20.350017352192058,
#  'фазовый_ADJF равновесие_NOUN': 20.34749123957702,
#  'капиллярный_ADJF электрофорез_NOUN': 20.342914899187797,
#  'практический_ADJF применение_NOUN': 20.33741859397288,
#  'флотационный_ADJF обогащение_NOUN': 20.335227668082037,
#  'питательный_ADJF среда_NOUN': 20.324147918811686,
#  'малый_ADJF степень_NOUN': 20.32330457992552,
#  'высокий_ADJF температура_NOUN': 20.318816876397378,
#  'горный_ADJF порода_NOUN': 20.30937976174644,
#  'мольный_ADJF соотношение_NOUN': 20.2957593255371,
#  'дипольный_ADJF момент_NOUN': 20.289817074665223,
#  'кинетический_ADJF модель_NOUN': 20.28074114157283,
#  'ароматический_ADJF углеводород_NOUN': 20.271014313018867,
#  'эндотермический_ADJF эффект_NOUN': 20.266823866297845,
#  'структурный_ADJF характеристика_NOUN': 20.260451545738658,
#  'инфракрасный_ADJF спектр_NOUN': 20.260339539915112,
#  'технологический_ADJF процесс_NOUN': 20.245369318245857,
#  'постоянный_ADJF перемешивание_NOUN': 20.24388599190694,
#  'длительный_ADJF время_NOUN': 20.241577149820518,
#  'электромагнитный_ADJF поле_NOUN': 20.23053599519731,
#  'древесный_ADJF опилка_NOUN': 20.230345372628914,
#  'бактериальный_ADJF клетка_NOUN': 20.217577231557662,
#  'кристаллический_ADJF фаза_NOUN': 20.208553803995162,
#  'количественный_ADJF определение_NOUN': 20.20758563700744,
#  'термогравиметрический_ADJF анализ_NOUN': 20.205783285876112,
#  'экзотермический_ADJF эффект_NOUN': 20.198577790501776,
#  'существенный_ADJF изменение_NOUN': 20.198454256165586,
#  'гигиенический_ADJF норматив_NOUN': 20.19755313131292,
#  'аммонийный_ADJF соль_NOUN': 20.194517280905696,
#  'научный_ADJF центр_NOUN': 20.189634864802176,
#  'электрический_ADJF проводимость_NOUN': 20.1891178161847,
#  'рентгеноструктурный_ADJF анализ_NOUN': 20.18903393577467,
#  'магниевый_ADJF сплав_NOUN': 20.18900731672714,
#  'оксидный_ADJF слой_NOUN': 20.18835566370731,
#  'окислительный_ADJF дегидрирование_NOUN': 20.185107531956543,
#  'настоящий_ADJF работа_NOUN': 20.18420563107089,
#  'активационный_ADJF барьер_NOUN': 20.183128186000086,
#  'трубчатый_ADJF печь_NOUN': 20.18212596145132,
#  'научный_ADJF сотрудник_NOUN': 20.17885247808364,
#  'сферический_ADJF форма_NOUN': 20.17277677636942,
#  'молекулярный_ADJF структура_NOUN': 20.171786339404097,
#  'газовый_ADJF хроматограф_NOUN': 20.169232796951164,
#  'инновационный_ADJF россия_NOUN': 20.163344917791388,
#  'защитный_ADJF действие_NOUN': 20.162575821315656,
#  'термоокислительный_ADJF деструкция_NOUN': 20.16138339488963,
#  'бензольный_ADJF кольцо_NOUN': 20.155242195057678,
#  'дифракционный_ADJF максимум_NOUN': 20.15449601282434,
#  'акриловый_ADJF кислота_NOUN': 20.15312094170214,
#  'лигандный_ADJF окружение_NOUN': 20.152726026208722,
#  'диффузный_ADJF отражение_NOUN': 20.149128591065754,
#  'поперечный_ADJF сечение_NOUN': 20.144535202431943,
#  'кислотный_ADJF гидролиз_NOUN': 20.116797085255502,
#  'широкий_ADJF полоса_NOUN': 20.114987492062014,
#  'ароматический_ADJF кольцо_NOUN': 20.11441172329147,
#  'межмолекулярный_ADJF взаимодействие_NOUN': 20.107314046285648,
#  'научный_ADJF семинар_NOUN': 20.101698528706233,
#  'высокий_ADJF эффективность_NOUN': 20.099838277795584,
#  'редкоземельный_ADJF металл_NOUN': 20.094089363198044,
#  'геометрический_ADJF параметр_NOUN': 20.092015220206356,
#  'кучный_ADJF выщелачивание_NOUN': 20.089967006522688,
#  'дисковый_ADJF электрод_NOUN': 20.074458558886462,
#  'уксусный_ADJF ангидрид_NOUN': 20.073795601179793,
#  'эксплуатационный_ADJF характеристика_NOUN': 20.070221427485656,
#  'градуировочный_ADJF график_NOUN': 20.06731522497374,
#  'низкий_ADJF стоимость_NOUN': 20.066555374982848,
#  'гидроксильный_ADJF группа_NOUN': 20.060480842037325,
#  'перспективный_ADJF направление_NOUN': 20.05090303773354,
#  'ударный_ADJF вязкость_NOUN': 20.047724695461806,
#  'электронный_ADJF микроскоп_NOUN': 20.040170628670346,
#  'вакуумный_ADJF перегонка_NOUN': 20.037373979632267,
#  'критический_ADJF точка_NOUN': 20.03566644134403,
#  'метильный_ADJF группа_NOUN': 20.03212690007804,
#  'стандартный_ADJF энтальпия_NOUN': 20.02912109369319,
#  'активный_ADJF центр_NOUN': 20.02381586364933,
#  'ромбический_ADJF сингония_NOUN': 20.009288734815577,
#  'вольфрамовый_ADJF бронза_NOUN': 20.001577749420264,
#  'промывный_ADJF вода_NOUN': 20.000467846128316,
#  'электрический_ADJF слой_NOUN': 19.99811882601157,
#  'ионный_ADJF радиус_NOUN': 19.992311576386168,
#  'лакокрасочный_ADJF материал_NOUN': 19.990316638561126,
#  'характеристический_ADJF полоса_NOUN': 19.982762254407245,
#  'ценный_ADJF компонент_NOUN': 19.982407397723744,
#  'контрольный_ADJF образец_NOUN': 19.972625929101024,
#  'кинетический_ADJF кривая_NOUN': 19.967351923170515,
#  'противокоррозионный_ADJF защита_NOUN': 19.95139919560982,
#  'нефтехимический_ADJF синтез_NOUN': 19.949837035049995,
#  'градуировочный_ADJF графика_NOUN': 19.947091900492023,
#  'экваториальный_ADJF плоскость_NOUN': 19.947057658811477,
#  'координационный_ADJF сфера_NOUN': 19.94033699637296,
#  'фундаментальный_ADJF исследование_NOUN': 19.936679990776913,
#  'молекулярный_ADJF орбиталь_NOUN': 19.93510563210039,
#  'концентрационный_ADJF зависимость_NOUN': 19.93223466828634,
#  'народный_ADJF хозяйство_NOUN': 19.929154006205103,
#  'экспериментальный_ADJF исследование_NOUN': 19.906874052620303,
#  'метрологический_ADJF характеристика_NOUN': 19.903876968959906,
#  'удельный_ADJF поверхность_NOUN': 19.897407544043936,
#  'различный_ADJF природа_NOUN': 19.89709934678262,
#  'бумажный_ADJF фильтр_NOUN': 19.89004416945205,
#  'энергетический_ADJF затрата_NOUN': 19.875688350907176,
#  'инфракрасный_ADJF спектроскопия_NOUN': 19.872167649032704,
#  'количественный_ADJF анализ_NOUN': 19.87078190745969,
#  'ректификационный_ADJF колонна_NOUN': 19.87075625954277,
#  'тепловой_ADJF поток_NOUN': 19.863167398676026,
#  'материальный_ADJF баланс_NOUN': 19.861692244588458,
#  'химический_ADJF промышленность_NOUN': 19.86161492284254,
#  'антимикробный_ADJF активность_NOUN': 19.851259007623923,
#  'редкий_ADJF элемент_NOUN': 19.84517461357226,
#  'равновесный_ADJF концентрация_NOUN': 19.841046420248414,
#  'нормативный_ADJF документ_NOUN': 19.827626005071927,
#  'паровой_ADJF конверсия_NOUN': 19.808698329280364,
#  'начальный_ADJF концентрация_NOUN': 19.806827373591556,
#  'научный_ADJF журнал_NOUN': 19.806114949321238,
#  'фосфорный_ADJF кислота_NOUN': 19.802291796522297,
#  'линейный_ADJF зависимость_NOUN': 19.794797834714714,
#  'термодинамический_ADJF характеристика_NOUN': 19.78393312199842,
#  'высокий_ADJF концентрация_NOUN': 19.783643877032027,
#  'водородный_ADJF связь_NOUN': 19.781923311450086,
#  'хороший_ADJF согласие_NOUN': 19.773046133599838,
#  'сточный_ADJF вода_NOUN': 19.77221932657227,
#  'силовой_ADJF микроскопия_NOUN': 19.770846828066894,
#  'парамагнитный_ADJF резонанс_NOUN': 19.770445561017873,
#  'фазовый_ADJF состав_NOUN': 19.765776666163987,
#  'слоистый_ADJF силикат_NOUN': 19.764152756552686,
#  'пористый_ADJF структура_NOUN': 19.761213114868454,
#  'ароматический_ADJF амин_NOUN': 19.761142709904597,
#  'рабочий_ADJF электрод_NOUN': 19.749452161438555,
#  'эпоксидный_ADJF олигомер_NOUN': 19.74811404781131,
#  'макромолекулярный_ADJF клубок_NOUN': 19.747335354015952,
#  'магнитный_ADJF поле_NOUN': 19.744538334993813,
#  'технический_ADJF университет_NOUN': 19.741466427914666,
#  'рентгеноспектральный_ADJF микроанализ_NOUN': 19.728503255851415,
#  'термодинамический_ADJF функция_NOUN': 19.721789479740703,
#  'кинетический_ADJF закономерность_NOUN': 19.720691758958054,
#  'межслоевой_ADJF пространство_NOUN': 19.70847512990188,
#  'сравнительный_ADJF оценка_NOUN': 19.70832460385866,
#  'трехвалентный_ADJF железо_NOUN': 19.708253384948645,
#  'российский_ADJF фонд_NOUN': 19.696900382658022,
#  'аммониевый_ADJF соль_NOUN': 19.694164601502358,
#  'жирный_ADJF кислота_NOUN': 19.690308952357697,
#  'количественный_ADJF оценка_NOUN': 19.68565748590636,
#  'нулевой_ADJF заряд_NOUN': 19.677052497248706,
#  'низкий_ADJF температура_NOUN': 19.673586556982535,
#  'стеклоуглеродный_ADJF электрод_NOUN': 19.667025649822662,
#  'технологический_ADJF университет_NOUN': 19.660665911208145,
#  'дифференциальный_ADJF уравнение_NOUN': 19.64848528871877,
#  'положительный_ADJF заряд_NOUN': 19.64553423194774,
#  'растительный_ADJF происхождение_NOUN': 19.64342515057766,
#  'лимонный_ADJF кислота_NOUN': 19.638767334760615,
#  'широкий_ADJF применение_NOUN': 19.621595932950868,
#  'кинетический_ADJF параметр_NOUN': 19.607205027313938,
#  'комнатный_ADJF температура_NOUN': 19.60545541810163,
#  'численный_ADJF значение_NOUN': 19.60082209143373,
#  'атмосферный_ADJF давление_NOUN': 19.591918098126406,
#  'палладиевый_ADJF катализатор_NOUN': 19.58567855195853,
#  'отрицательный_ADJF заряд_NOUN': 19.57227338897147,
#  'ферментативный_ADJF гидролиз_NOUN': 19.566884962416662,
#  'адсорбционный_ADJF способность_NOUN': 19.56437631320329,
#  'предварительный_ADJF обработка_NOUN': 19.563017901126916,
#  'биологический_ADJF активность_NOUN': 19.56110534223817,
#  'ионный_ADJF обмен_NOUN': 19.553503134178325,
#  'адсорбционный_ADJF слой_NOUN': 19.53937550615223,
#  'ртутный_ADJF лампа_NOUN': 19.537959190634034,
#  'электрокинетический_ADJF потенциал_NOUN': 19.526656328413043,
#  'центральный_ADJF атом_NOUN': 19.525241498346492,
#  'каталитический_ADJF активность_NOUN': 19.522843607324315,
#  'ионизационный_ADJF детектор_NOUN': 19.518619455018577,
#  'серный_ADJF кислота_NOUN': 19.504033916705154,
#  'взаимный_ADJF расположение_NOUN': 19.50030113682446,
#  'фосфорнокислый_ADJF катионит_NOUN': 19.500241453989076,
#  'марганцевый_ADJF руда_NOUN': 19.491790684926617,
#  'коричневый_ADJF цвет_NOUN': 19.490258306042605,
#  'третичный_ADJF амин_NOUN': 19.488462064822837,
#  'дизельный_ADJF топливо_NOUN': 19.48126167481255,
#  'азотный_ADJF кислота_NOUN': 19.480289736285215,
#  'цементный_ADJF камень_NOUN': 19.479796742381396,
#  'жидкостный_ADJF хроматограф_NOUN': 19.478157369934035,
#  'магнитный_ADJF резонанс_NOUN': 19.475768423688713,
#  'водный_ADJF раствор_NOUN': 19.47148237820528,
#  'винный_ADJF кислота_NOUN': 19.471479718732496,
#  'неорганический_ADJF химия_NOUN': 19.465930194263034,
#  'стальной_ADJF мембрана_NOUN': 19.464523001830983,
#  'гуминовый_ADJF вещество_NOUN': 19.46133854909904,
#  'диффузионный_ADJF ограничение_NOUN': 19.46051480618083,
#  'ртутный_ADJF капля_NOUN': 19.45963315554061,
#  'нержавеющий_ADJF сталь_NOUN': 19.448170596428753,
#  'низкий_ADJF концентрация_NOUN': 19.44326610329248,
#  'микроскопический_ADJF снимок_NOUN': 19.43005165769359,
#  'каталитический_ADJF свойство_NOUN': 19.429441365068524,
#  'базисный_ADJF набор_NOUN': 19.42877685193608,
#  'бромистый_ADJF аллил_NOUN': 19.427465578490494,
#  'пищевой_ADJF продукт_NOUN': 19.426474155960396,
#  'соляный_ADJF кислота_NOUN': 19.425397609658017,
#  'коллоидный_ADJF химия_NOUN': 19.41006341024878,
#  'электронный_ADJF ресурс_NOUN': 19.395146206059664,
#  'щелочной_ADJF раствор_NOUN': 19.390164502293104,
#  'приповерхностный_ADJF слой_NOUN': 19.383224277398707,
#  'сульфидный_ADJF минерал_NOUN': 19.3801806726383,
#  'рентгеновский_ADJF луч_NOUN': 19.375686527534267,
#  'пассивный_ADJF состояние_NOUN': 19.37542901442147,
#  'тройной_ADJF система_NOUN': 19.372132531885487,
#  'углеводородный_ADJF радикал_NOUN': 19.369235334445733,
#  'длительный_ADJF хранение_NOUN': 19.368549283095557,
#  'удельный_ADJF электропроводность_NOUN': 19.36459351133367,
#  'нижний_ADJF граница_NOUN': 19.363452974742426,
#  'аммиачный_ADJF селитра_NOUN': 19.363256370043263,
#  'угловой_ADJF коэффициент_NOUN': 19.36088155645578,
#  'химический_ADJF метод_NOUN': 19.358851226587046,
#  'гидролизный_ADJF лигнин_NOUN': 19.355659646507508,
#  'молочный_ADJF сыворотка_NOUN': 19.348426754280364,
#  'ферментный_ADJF препарат_NOUN': 19.346938310723917,
#  'подвижный_ADJF фаза_NOUN': 19.343048917226575,
#  'отрицательный_ADJF значение_NOUN': 19.342354239413627,
#  'фильтровальный_ADJF бумага_NOUN': 19.335672939543468,
#  'углеродный_ADJF нанотрубка_NOUN': 19.335226621261913,
#  'больший_ADJF количество_NOUN': 19.334639761934657,
#  'токовый_ADJF нагрузка_NOUN': 19.32917426206797,
#  'углеродный_ADJF волокно_NOUN': 19.325726432338694,
#  'вспомогательный_ADJF электрод_NOUN': 19.31324980892749,
#  'изоморфный_ADJF замещение_NOUN': 19.30346052853937,
#  'апротонный_ADJF растворитель_NOUN': 19.301315723109283,
#  'платиновый_ADJF тигль_NOUN': 19.298312416350775,
#  'межатомный_ADJF расстояние_NOUN': 19.297322947216948,
#  'алифатический_ADJF спирт_NOUN': 19.297005498238768,
#  'полный_ADJF удаление_NOUN': 19.293916298912357,
#  'экспериментальный_ADJF данные_NOUN': 19.2888113684032,
#  'поровый_ADJF пространство_NOUN': 19.287834478229453,
#  'значительный_ADJF степень_NOUN': 19.286783984889766,
#  'цинковый_ADJF пыль_NOUN': 19.276400252074826,
#  'стехиометрический_ADJF коэффициент_NOUN': 19.27608693079879,
#  'экстремальный_ADJF характер_NOUN': 19.27248862180368,
#  'большой_ADJF интерес_NOUN': 19.27159167362464,
#  'химический_ADJF реакция_NOUN': 19.263249248543104,
#  'полимерный_ADJF материал_NOUN': 19.257428989042374,
#  'экспериментальный_ADJF значение_NOUN': 19.24904411267171,
#  'мольный_ADJF доля_NOUN': 19.248373561936603,
#  'химический_ADJF анализ_NOUN': 19.233703778538064,
#  'активный_ADJF вещество_NOUN': 19.232713004947513,
#  'стехиометрический_ADJF соотношение_NOUN': 19.22586674176476,
#  'промежуточный_ADJF продукт_NOUN': 19.224138422887226,
#  'щелочной_ADJF металл_NOUN': 19.220727915371832,
#  'рисовый_ADJF шелуха_NOUN': 19.22010868354843,
#  'калибровочный_ADJF графика_NOUN': 19.20976107908948,
#  'эфирный_ADJF масло_NOUN': 19.202290197642604,
#  'элементный_ADJF анализ_NOUN': 19.201427575931085,
#  'спектральный_ADJF характеристика_NOUN': 19.201174903502686,
#  'эпоксидный_ADJF смола_NOUN': 19.196457625842264,
#  'педагогический_ADJF кадр_NOUN': 19.19419748136646,
#  'гуминовый_ADJF кислота_NOUN': 19.19305909382446,
#  'пластовый_ADJF вода_NOUN': 19.19218700513682,
#  'квантовый_ADJF выход_NOUN': 19.183488236008518,
#  'методический_ADJF семинар_NOUN': 19.18269224515896,
#  'двойной_ADJF связь_NOUN': 19.180513212128393,
#  'температурный_ADJF интервал_NOUN': 19.178371806020785,
#  'паровой_ADJF фаза_NOUN': 19.176414238058662,
#  'электрический_ADJF взрыв_NOUN': 19.17304500436792,
#  'технический_ADJF наука_NOUN': 19.15835893414879,
#  'натриевый_ADJF соль_NOUN': 19.154297490753436,
#  'неподвижный_ADJF фаза_NOUN': 19.150869086006622,
#  'структурный_ADJF формула_NOUN': 19.150153395125304,
#  'электрохимический_ADJF ячейка_NOUN': 19.1421316521236,
#  'гидравлический_ADJF сопротивление_NOUN': 19.131963927145968,
#  'клеточный_ADJF стенка_NOUN': 19.113462300671014,
#  'предельный_ADJF ток_NOUN': 19.105790011447624,
#  'электрохимический_ADJF поведение_NOUN': 19.1052015468511,
#  'двухвалентный_ADJF железо_NOUN': 19.104258858737538,
#  'термический_ADJF разложение_NOUN': 19.097055589850186,
#  'свободный_ADJF энергия_NOUN': 19.09681558359066,
#  'колоночный_ADJF хроматография_NOUN': 19.09561463177633,
#  'ведущий_ADJF инженер_NOUN': 19.094106820854282,
#  'свободный_ADJF радикал_NOUN': 19.09125877976927,
#  'научный_ADJF труд_NOUN': 19.087177835002876,
#  'химический_ADJF наука_NOUN': 19.085120037152606,
#  'аминокислотный_ADJF остаток_NOUN': 19.07764298087939,
#  'янтарный_ADJF кислота_NOUN': 19.068387337423022,
#  'плотный_ADJF упаковка_NOUN': 19.067569475981294,
#  'топливный_ADJF элемент_NOUN': 19.062482027479366,
#  'активный_ADJF компонент_NOUN': 19.06106940243208,
#  'жидкостный_ADJF хроматография_NOUN': 19.06064707275613,
#  'природный_ADJF цеолит_NOUN': 19.05851737477958,
#  'практический_ADJF конференция_NOUN': 19.05734978154577,
#  'горючий_ADJF ископаемое_NOUN': 19.05481000122875,
#  'авиационный_ADJF материал_NOUN': 19.048435951132387,
#  'метиловый_ADJF эфир_NOUN': 19.042613070422334,
#  'салициловый_ADJF кислота_NOUN': 19.032253456758397,
#  'протонный_ADJF проводимость_NOUN': 19.02681251724132,
#  'бутиловый_ADJF спирт_NOUN': 19.02370369773206,
#  'химический_ADJF превращение_NOUN': 19.01441139709353,
#  'дифракционный_ADJF картина_NOUN': 19.005736400935458,
#  'калибровочный_ADJF график_NOUN': 19.004287917550116,
#  'научный_ADJF стать_NOUN': 19.00384499738423,
#  'щавелевый_ADJF кислота_NOUN': 19.000094893912156,
#  'хлористый_ADJF водород_NOUN': 18.998717903472222,
#  'учебный_ADJF пособие_NOUN': 18.998008944347415,
#  'зубной_ADJF камень_NOUN': 18.980716448253457,
#  'ацетатный_ADJF буфер_NOUN': 18.96226931635501,
#  'олеиновый_ADJF кислота_NOUN': 18.948857618866437,
#  'групповой_ADJF состав_NOUN': 18.942096482947914,
#  'фенольный_ADJF соединение_NOUN': 18.938574234762168,
#  'стеариновый_ADJF кислота_NOUN': 18.929082091354726,
#  'принципиальный_ADJF возможность_NOUN': 18.92602853944712,
#  'электронный_ADJF микроскопия_NOUN': 18.916095129700427,
#  'защитный_ADJF эффект_NOUN': 18.915673026727003,
#  'красящий_ADJF вещество_NOUN': 18.9061546357602,
#  'плазмохимический_ADJF нанотехнология_NOUN': 18.9059188917183,
#  'ионный_ADJF сила_NOUN': 18.90365758673094,
#  'инертный_ADJF газ_NOUN': 18.901029270462104,
#  'жидкий_ADJF продукт_NOUN': 18.892804579429924,
#  'калийный_ADJF удобрение_NOUN': 18.892230874743202,
#  'изотермический_ADJF выдержка_NOUN': 18.892081998048074,
#  'белый_ADJF цвет_NOUN': 18.887931567463763,
#  'русский_ADJF язык_NOUN': 18.887317207425827,
#  'катионный_ADJF полиэлектролит_NOUN': 18.883334281791363,
#  'органический_ADJF вещество_NOUN': 18.8829484591085,
#  'тонкий_ADJF слой_NOUN': 18.88231177239571,
#  'импедансный_ADJF спектроскопия_NOUN': 18.877156253264165,
#  'газовый_ADJF фаза_NOUN': 18.872141850162578,
#  'холостой_ADJF опыт_NOUN': 18.865741476531326,
#  'субстратный_ADJF специфичность_NOUN': 18.86194468962874,
#  'бутиловый_ADJF эфир_NOUN': 18.857231027603515,
#  'органический_ADJF химия_NOUN': 18.854858639655962,
#  'сольватный_ADJF оболочка_NOUN': 18.852262582326507,
#  'углекислый_ADJF газ_NOUN': 18.844701630391288,
#  'переходный_ADJF металл_NOUN': 18.841263171079966,
#  'термический_ADJF деструкция_NOUN': 18.84036435445103,
#  'тонкослойный_ADJF хроматография_NOUN': 18.83973200221319,
#  'углеродный_ADJF наноматериал_NOUN': 18.838917056332207,
#  'процентный_ADJF содержание_NOUN': 18.837609031051297,
#  'ароматический_ADJF нитросоединение_NOUN': 18.830577151868894,
#  'жидкий_ADJF фаза_NOUN': 18.82678299709041,
#  'пектиновый_ADJF вещество_NOUN': 18.824272511070575,
#  'нитрильный_ADJF каучук_NOUN': 18.814947145187123,
#  'термический_ADJF обработка_NOUN': 18.810240304428657,
#  'термический_ADJF устойчивость_NOUN': 18.799021774414452,
#  'редкоземельный_ADJF элемент_NOUN': 18.794856264469125,
#  'фталевый_ADJF ангидрид_NOUN': 18.788020547111856,
#  'пектиновый_ADJF полисахарид_NOUN': 18.783919714412466,
#  'кубовый_ADJF остаток_NOUN': 18.77587635044697,
#  'борный_ADJF кислота_NOUN': 18.77279289826062,
#  'малый_ADJF квадрат_NOUN': 18.7717884506093,
#  'алюмохромовый_ADJF катализатор_NOUN': 18.76583888528491,
#  'электрический_ADJF поле_NOUN': 18.760309573934297,
#  'сельскохозяйственный_ADJF культура_NOUN': 18.756380604737064,
#  'сухой_ADJF вещество_NOUN': 18.75337289402556,
#  'диэлектрический_ADJF потеря_NOUN': 18.750307487413743,
#  'повышенный_ADJF температура_NOUN': 18.74952666688132,
#  'растительный_ADJF масло_NOUN': 18.741832864669068,
#  'малеиновый_ADJF ангидрид_NOUN': 18.741139921874506,
#  'каменноугольный_ADJF пек_NOUN': 18.735006198307058,
#  'виниловый_ADJF мономер_NOUN': 18.72732951161171,
#  'исходный_ADJF концентрация_NOUN': 18.72399353829166,
#  'сырьевой_ADJF база_NOUN': 18.72397358956473,
#  'хозяйственный_ADJF деятельность_NOUN': 18.72022719606365,
#  'аммонийный_ADJF селитра_NOUN': 18.72017204448978,
#  'практический_ADJF руководство_NOUN': 18.706482664620065,
#  'потенциальный_ADJF энергия_NOUN': 18.70162536404912,
#  'полиморфный_ADJF превращение_NOUN': 18.701511407776035,
#  'массовый_ADJF распределение_NOUN': 18.701076944722804,
#  'дисперсный_ADJF фаза_NOUN': 18.70006771368887,
#  'подземный_ADJF вода_NOUN': 18.69174260818563,
#  'внутренний_ADJF диаметр_NOUN': 18.691473544839205,
#  'кордиеритовый_ADJF ситалл_NOUN': 18.68630068386956,
#  'трехэлектродный_ADJF ячейка_NOUN': 18.682996248479974,
#  'готовый_ADJF продукция_NOUN': 18.679250506294842,
#  'инертный_ADJF атмосфера_NOUN': 18.678181546613654,
#  'электронный_ADJF удар_NOUN': 18.672970417128333,
#  'боратный_ADJF буфер_NOUN': 18.663067464185684,
#  'фазовый_ADJF превращение_NOUN': 18.662725740228286,
#  'солянокислый_ADJF гидроксиламин_NOUN': 18.66237671389748,
#  'наружный_ADJF мисцелла_NOUN': 18.652033040430148,
#  'кажущийся_ADJF энергия_NOUN': 18.6519264145695,
#  'мономолекулярный_ADJF распад_NOUN': 18.649059265068388,
#  'равномерный_ADJF распределение_NOUN': 18.646579042300854,
#  'вибрационный_ADJF мельница_NOUN': 18.641153230239976,
#  'средний_ADJF значение_NOUN': 18.639821992121362,
#  'динамический_ADJF вязкость_NOUN': 18.63757717965202,
#  'жидкостный_ADJF экстракция_NOUN': 18.635795000514992,
#  'азотистый_ADJF основание_NOUN': 18.633237322736992,
#  'остаточный_ADJF концентрация_NOUN': 18.629007762056986,
#  'красный_ADJF цвет_NOUN': 18.627090054771408,
#  'целевой_ADJF продукт_NOUN': 18.622265511208678,
#  'полиэфирный_ADJF смола_NOUN': 18.619404974243484,
#  'переходный_ADJF состояние_NOUN': 18.61602701870253,
#  'концентрированный_ADJF раствор_NOUN': 18.61090500379871,
#  'сульфгидрильный_ADJF собиратель_NOUN': 18.60740521376302,
#  'аналитический_ADJF сигнал_NOUN': 18.60601677582908,
#  'сухой_ADJF остаток_NOUN': 18.604528754548333,
#  'бинарный_ADJF смесь_NOUN': 18.599238820710337,
#  'цветной_ADJF металл_NOUN': 18.590331221044995,
#  'подсолнечный_ADJF масло_NOUN': 18.590063505807446,
#  'малый_ADJF количество_NOUN': 18.585276304660084,
#  'лабораторный_ADJF условие_NOUN': 18.58446907060214,
#  'древесный_ADJF мука_NOUN': 18.56741568752767,
#  'косвенный_ADJF подтверждение_NOUN': 18.566283168377005,
#  'донный_ADJF отложение_NOUN': 18.56566229339054,
#  'коптильный_ADJF дым_NOUN': 18.561466748350913,
#  'электродный_ADJF процесс_NOUN': 18.56084588017251,
#  'полисульфидный_ADJF олигомер_NOUN': 18.550538740788475,
#  'особый_ADJF место_NOUN': 18.546237258905883,
#  'ионный_ADJF аккумулятор_NOUN': 18.521072950685433,
#  'сульфатный_ADJF лигнин_NOUN': 18.520097970184967,
#  'следующий_ADJF схема_NOUN': 18.491978769072407,
#  'средний_ADJF диаметр_NOUN': 18.489762627278882,
#  'гликозидный_ADJF связь_NOUN': 18.48547872060254,
#  'литературный_ADJF данные_NOUN': 18.48381232145,
#  'активный_ADJF уголь_NOUN': 18.47765340150333,
#  'водный_ADJF среда_NOUN': 18.4657142826663,
#  'физический_ADJF химия_NOUN': 18.465456151631493,
#  'дальнейший_ADJF повышение_NOUN': 18.459681503834062,
#  'органический_ADJF синтез_NOUN': 18.449604810786226,
#  'наш_ADJF страна_NOUN': 18.44476438196163,
#  'краткий_ADJF сообщение_NOUN': 18.43932679078162,
#  'стандартный_ADJF методика_NOUN': 18.438304764885995,
#  'переменный_ADJF валентность_NOUN': 18.435763757849443,
#  'постоянный_ADJF масса_NOUN': 18.435609218351356,
#  'существенный_ADJF недостаток_NOUN': 18.431039598371903,
#  'калиевый_ADJF соль_NOUN': 18.419037689588514,
#  'бурый_ADJF уголь_NOUN': 18.39855161066386,
#  'полимерный_ADJF композиция_NOUN': 18.3969826887705,
#  'фазовый_ADJF переход_NOUN': 18.391274881001756,
#  'кварцевый_ADJF песок_NOUN': 18.390893676473762,
#  'ароматический_ADJF ядро_NOUN': 18.38969019064847,
#  'алюминиевый_ADJF фольга_NOUN': 18.382714335472556,
#  'валентный_ADJF угол_NOUN': 18.379326011805723,
#  'визуальный_ADJF наблюдение_NOUN': 18.37574606220135,
#  'математический_ADJF статистика_NOUN': 18.37238251154821,
#  'муравьиный_ADJF кислота_NOUN': 18.370946049778958,
#  'точный_ADJF навеска_NOUN': 18.36747733350492,
#  'сплошной_ADJF линия_NOUN': 18.36703802581245,
#  'этиловый_ADJF эфир_NOUN': 18.36665565371258,
#  'дальнейший_ADJF увеличение_NOUN': 18.365477981085593,
#  'органический_ADJF соединение_NOUN': 18.354948834795902,
#  'тепловой_ADJF эффект_NOUN': 18.353457668744944,
#  'потенциальный_ADJF барьер_NOUN': 18.34857633283076,
#  'функциональный_ADJF группа_NOUN': 18.347955778920998,
#  'сравнительный_ADJF анализ_NOUN': 18.33789368804524,
#  'текстурный_ADJF характеристика_NOUN': 18.334392884037772,
#  'восточный_ADJF сибирь_NOUN': 18.320536561393848,
#  'кислотный_ADJF центр_NOUN': 18.315461538381978,
#  'метиловый_ADJF спирт_NOUN': 18.3137776647832,
#  'известковый_ADJF молоко_NOUN': 18.30110200673771,
#  'полезный_ADJF ископаемое_NOUN': 18.29796206836915,
#  'диффузионный_ADJF сок_NOUN': 18.292960233598954,
#  'термический_ADJF распад_NOUN': 18.28423058476661,
#  'газовый_ADJF хроматография_NOUN': 18.283820331436704,
#  'многокомпонентный_ADJF система_NOUN': 18.279398214786166,
#  'химический_ADJF состав_NOUN': 18.272075375585416,
#  'больший_ADJF часть_NOUN': 18.266122418359046,
#  'приоритетный_ADJF направление_NOUN': 18.261258139112236,
#  'западный_ADJF сибирь_NOUN': 18.257410738572005,
#  'среднеквадратичный_ADJF отклонение_NOUN': 18.2408281570644,
#  'резиновый_ADJF смесь_NOUN': 18.240409183633957,
#  'молекулярный_ADJF кислород_NOUN': 18.23723472208856,
#  'широкий_ADJF диапазон_NOUN': 18.23560075306595,
#  'физический_ADJF смысл_NOUN': 18.22997384756214,
#  'комплексный_ADJF переработка_NOUN': 18.229178104330618,
#  'жидкофазный_ADJF окисление_NOUN': 18.226190136059287,
#  'ионный_ADJF жидкость_NOUN': 18.218553095496887,
#  'зондовый_ADJF микроскоп_NOUN': 18.21834407006342,
#  'морской_ADJF вода_NOUN': 18.21489448926597,
#  'костный_ADJF ткань_NOUN': 18.198269730362224,
#  'изоэлектрический_ADJF точка_NOUN': 18.191267591704054,
#  'устойчивый_ADJF развитие_NOUN': 18.184324118904737,
#  'эластомерный_ADJF композиция_NOUN': 18.183257442642233,
#  'большой_ADJF внимание_NOUN': 18.17972321840597,
#  'углеродистый_ADJF сталь_NOUN': 18.171106053443864,
#  'тепловой_ADJF расширение_NOUN': 18.152306240438726,
#  'газофазный_ADJF распад_NOUN': 18.146449562737033,
#  'щелочной_ADJF среда_NOUN': 18.14152335353752,
#  'незначительный_ADJF количество_NOUN': 18.131522709928063,
#  'графитовый_ADJF монохроматор_NOUN': 18.1273367131197,
#  'гидратный_ADJF оболочка_NOUN': 18.122266398875354,
#  'краевой_ADJF угол_NOUN': 18.120900364571597,
#  'относительный_ADJF ошибка_NOUN': 18.115673327019127,
#  'сушильный_ADJF шкаф_NOUN': 18.099185357975216,
#  'гетерогенный_ADJF катализ_NOUN': 18.094108838564715,
#  'российский_ADJF химико_NOUN': 18.093296456889,
#  'аналитический_ADJF весы_NOUN': 18.084963865920226,
#  'хлористый_ADJF метилен_NOUN': 18.08146887260128,
#  'электронный_ADJF плотность_NOUN': 18.076916854567312,
#  'нитратный_ADJF группа_NOUN': 18.0736184351783,
#  'окислительный_ADJF стресс_NOUN': 18.07250902572529,
#  'катионный_ADJF полимеризация_NOUN': 18.0710807090615,
#  'циклический_ADJF вольтамперограмма_NOUN': 18.06734579695578,
#  'линейный_ADJF участок_NOUN': 18.064853998627402,
#  'начальный_ADJF момент_NOUN': 18.059654243764832,
#  'значительный_ADJF количество_NOUN': 18.043800315514503,
#  'относительный_ADJF погрешность_NOUN': 18.04225417480387,
#  'синий_ADJF лента_NOUN': 18.034485480801045,
#  'реакционный_ADJF смесь_NOUN': 18.02410520254084,
#  'широкий_ADJF распространение_NOUN': 18.02280765928951,
#  'бурый_ADJF водоросль_NOUN': 18.01554047149202,
#  'относительный_ADJF интенсивность_NOUN': 18.01486795888907,
#  'термический_ADJF стабильность_NOUN': 18.010232802988018,
#  'рабочий_ADJF частота_NOUN': 17.998136699181888,
#  'особый_ADJF внимание_NOUN': 17.996335173612824,
#  'шинный_ADJF резина_NOUN': 17.99607871292896,
#  'элементный_ADJF состав_NOUN': 17.987743377789197,
#  'волокнистый_ADJF полуфабрикат_NOUN': 17.971281539705505,
#  'координационный_ADJF число_NOUN': 17.966207336900442,
#  'воздушный_ADJF среда_NOUN': 17.957892544021433,
#  'циклический_ADJF вольтамперометрия_NOUN': 17.947444037536794,
#  'стандартный_ADJF отклонение_NOUN': 17.945954378724828,
#  'всесоюзный_ADJF совещание_NOUN': 17.94368093645732,
#  'поглотительный_ADJF способность_NOUN': 17.9274799828893,
#  'фенольный_ADJF гидроксил_NOUN': 17.91217692749465,
#  'небольшой_ADJF количество_NOUN': 17.90111114065506,
#  'слабый_ADJF поле_NOUN': 17.895097610725966,
#  'низинный_ADJF торф_NOUN': 17.894997345811493,
#  'этиловый_ADJF спирт_NOUN': 17.875190910251728,
#  'индукционный_ADJF период_NOUN': 17.86889333089114,
#  'полимерный_ADJF цепь_NOUN': 17.86543540300054,
#  'новый_ADJF поколение_NOUN': 17.86276949334883,
#  'органический_ADJF растворитель_NOUN': 17.853807641939117,
#  'насыщенный_ADJF раствор_NOUN': 17.852092384765044,
#  'полимерный_ADJF матрица_NOUN': 17.85000023767649,
#  'условный_ADJF обозначение_NOUN': 17.849285906161043,
#  'дисперсионный_ADJF среда_NOUN': 17.84053873552139,
#  'цветной_ADJF металлургия_NOUN': 17.833886901004252,
#  'мольный_ADJF отношение_NOUN': 17.833260791051668,
#  'пластический_ADJF масса_NOUN': 17.83033528302946,
#  'статический_ADJF условие_NOUN': 17.825257456693702,
#  'окружающий_ADJF среда_NOUN': 17.81733056796472,
#  'интенсивный_ADJF перемешивание_NOUN': 17.807877411418342,
#  'несомненный_ADJF интерес_NOUN': 17.802672060225305,
#  'экологический_ADJF обстановка_NOUN': 17.80251922973183,
#  'синхронный_ADJF термоанализатор_NOUN': 17.796727671797157,
#  'термический_ADJF анализ_NOUN': 17.793541827733762,
#  'брутто_ADJF формула_NOUN': 17.78926359307088,
#  'фарфоровый_ADJF чашка_NOUN': 17.775293056454974,
#  'сульфатный_ADJF скипидар_NOUN': 17.76713725189977,
#  'комплексный_ADJF соединение_NOUN': 17.762737242871687,
#  'заводский_ADJF лаборатория_NOUN': 17.75852334869323,
#  'лиственный_ADJF порода_NOUN': 17.75271979603439,
#  'начальный_ADJF стадия_NOUN': 17.752090222969272,
#  'высокомолекулярный_ADJF соединение_NOUN': 17.749284677639245,
#  'газовый_ADJF смесь_NOUN': 17.74759018337136,
#  'фосфатный_ADJF буфер_NOUN': 17.729761028261105,
#  'уральский_ADJF отделение_NOUN': 17.726827095736848,
#  'меховой_ADJF полуфабрикат_NOUN': 17.70537509990692,
#  'алюмооксидный_ADJF носитель_NOUN': 17.702881496641826,
#  'водяной_ADJF паром_NOUN': 17.70223858292745,
#  'жидкий_ADJF стекло_NOUN': 17.69361817061632,
#  'исходный_ADJF компонент_NOUN': 17.692572533388102,
#  'следующий_ADJF образ_NOUN': 17.692125376011326,
#  'стандартный_ADJF образец_NOUN': 17.68584692160936,
#  'водный_ADJF фаза_NOUN': 17.68305649401641,
#  'сибирский_ADJF отделение_NOUN': 17.67396223744746,
#  'углеродный_ADJF скелет_NOUN': 17.667947137060796,
#  'средний_ADJF размер_NOUN': 17.655013150043086,
#  'литературный_ADJF источник_NOUN': 17.650674939456476,
#  'карбоновый_ADJF кислота_NOUN': 17.648154560430076,
#  'пропионовый_ADJF кислота_NOUN': 17.63766851058275,
#  'финансовый_ADJF поддержка_NOUN': 17.63362893279502,
#  'различный_ADJF концентрация_NOUN': 17.63147500980377,
#  'храпковский_ADJF вестник_NOUN': 17.630096010088703,
#  'основный_ADJF компонент_NOUN': 17.6287583883258,
#  'исходный_ADJF раствор_NOUN': 17.6283297314638,
#  'активированный_ADJF уголь_NOUN': 17.618757587257758,
#  'мягкий_ADJF условие_NOUN': 17.61693160615537,
#  'видимый_ADJF область_NOUN': 17.610944392825008,
#  'калориметрический_ADJF бомба_NOUN': 17.609020730121006,
#  'элементарный_ADJF акт_NOUN': 17.605200021423382,
#  'обратный_ADJF холодильник_NOUN': 17.6045691740914,
#  'химический_ADJF сдвиг_NOUN': 17.599791884352445,
#  'кислый_ADJF среда_NOUN': 17.578002115897167,
#  'диполярный_ADJF циклоприсоединение_NOUN': 17.57709349304466,
#  'мышечный_ADJF ткань_NOUN': 17.575373755943104,
#  'молибденовый_ADJF синь_NOUN': 17.564812138817885,
#  'зольный_ADJF микросфера_NOUN': 17.563100488073726,
#  'неорганический_ADJF вещество_NOUN': 17.56228344570103,
#  'нейтральный_ADJF среда_NOUN': 17.555023739663593,
#  'технологический_ADJF схема_NOUN': 17.550138990683195,
#  'массовый_ADJF доля_NOUN': 17.5464713744201,
#  'кристаллизационный_ADJF вода_NOUN': 17.54373293301049,
#  'настоящий_ADJF время_NOUN': 17.532755453446885,
#  'широкий_ADJF круг_NOUN': 17.53028151547353,
#  'биохимический_ADJF физика_NOUN': 17.524645554704986,
#  'методический_ADJF указание_NOUN': 17.52207482161557,
#  'сверхкритический_ADJF флюид_NOUN': 17.517739583376404,
#  'кировский_ADJF омск_NOUN': 17.514548379035727,
#  'компонентный_ADJF состав_NOUN': 17.510744098493387,
#  'кремнекислородный_ADJF тетраэдр_NOUN': 17.48198781135664,
#  'хромовый_ADJF дубление_NOUN': 17.48098240639338,
#  'томский_ADJF орден_NOUN': 17.4637985341378,
#  'гидравлический_ADJF пресса_NOUN': 17.461279435876136,
#  'синтетический_ADJF каучук_NOUN': 17.458066824609922,
#  'дальнейший_ADJF исследование_NOUN': 17.450033045781783,
#  'бутиловый_ADJF ксантогенат_NOUN': 17.44726880007323,
#  'первый_ADJF стадия_NOUN': 17.446669610648225,
#  'интегральный_ADJF интенсивность_NOUN': 17.43926449606966,
#  'структурный_ADJF единица_NOUN': 17.426051571335464,
#  'синергетический_ADJF эффект_NOUN': 17.423355032352195,
#  'взрывной_ADJF автогидролиз_NOUN': 17.418211443590444,
#  'гранулометрический_ADJF состав_NOUN': 17.41591337084298,
#  'аналитический_ADJF химия_NOUN': 17.404480945391317,
#  'нефтепромысловый_ADJF оборудование_NOUN': 17.39088142225696,
#  'нисходящий_ADJF ветвь_NOUN': 17.388724332414373,
#  'фарфоровый_ADJF ступка_NOUN': 17.362395808826,
#  'широкий_ADJF интервал_NOUN': 17.35856842817032,
#  'реакционный_ADJF масса_NOUN': 17.355585838481865,
#  'рецепторный_ADJF элемент_NOUN': 17.355159260294442,
#  'водный_ADJF вытяжка_NOUN': 17.347857978404292,
#  'реакционный_ADJF способность_NOUN': 17.331499853909623,
#  'большой_ADJF количество_NOUN': 17.32705251693473,
#  'шаровой_ADJF мельница_NOUN': 17.32508057824047,
#  'второй_ADJF стадия_NOUN': 17.320788482623275,
#  'природный_ADJF газ_NOUN': 17.318143467699787,
#  'условный_ADJF прочность_NOUN': 17.305599730485792,
#  'свой_ADJF состав_NOUN': 17.305149789285107,
#  'кремниевый_ADJF кислота_NOUN': 17.30273672410349,
#  'конечный_ADJF продукт_NOUN': 17.301667913335915,
#  'водопроводный_ADJF вода_NOUN': 17.294367026495987,
#  'спиртовой_ADJF раствор_NOUN': 17.288445667936085,
#  'тритерпеновый_ADJF гликозид_NOUN': 17.28582094028259,
#  'пшеничный_ADJF солома_NOUN': 17.28471625440881,
#  'реакционный_ADJF центр_NOUN': 17.266645255451763,
#  'почвенный_ADJF покров_NOUN': 17.26396083596075,
#  'благородный_ADJF металл_NOUN': 17.263169999496682,
#  'широкий_ADJF предел_NOUN': 17.253440728087543,
#  'промышленный_ADJF масштаб_NOUN': 17.250063089241177,
#  'красный_ADJF шлам_NOUN': 17.24693963263107,
#  'этот_ADJF условие_NOUN': 17.22715105025178,
#  'экстрактивный_ADJF вещество_NOUN': 17.216964902466042,
#  'относительный_ADJF влажность_NOUN': 17.215934154339624,
#  'электрофоретический_ADJF подвижность_NOUN': 17.21326803685693,
#  'реакционный_ADJF среда_NOUN': 17.207433191899643,
#  'пожарный_ADJF безопасность_NOUN': 17.2050484043435,
#  'принципиальный_ADJF схема_NOUN': 17.202960808382304,
#  'модельный_ADJF раствор_NOUN': 17.185161988743726,
#  'мерный_ADJF колба_NOUN': 17.18457643081467,
#  'ионообменный_ADJF смола_NOUN': 17.16203315605666,
#  'суммарный_ADJF содержание_NOUN': 17.132330705253054,
#  'виноградный_ADJF выжимка_NOUN': 17.127542169855563,
#  'хозяйственный_ADJF мыло_NOUN': 17.10896632915209,
#  'каталитический_ADJF система_NOUN': 17.104639772368646,
#  'сложный_ADJF эфир_NOUN': 17.10318951936165,
#  'целевой_ADJF программа_NOUN': 17.0989282686202,
#  'газожидкостный_ADJF хроматография_NOUN': 17.097156433158844,
#  'оптический_ADJF плотность_NOUN': 17.096762754928534,
#  'литьевой_ADJF полиуретан_NOUN': 17.09563960375512,
#  'теоретический_ADJF основа_NOUN': 17.081854203596826,
#  'значительный_ADJF мера_NOUN': 17.072510286793666,
#  'известный_ADJF методика_NOUN': 17.0659179000442,
#  'исходный_ADJF вещество_NOUN': 17.059373251868003,
#  'первый_ADJF этап_NOUN': 17.057999546408986,
#  'относительный_ADJF удлинение_NOUN': 17.0577060700824,
#  'систематический_ADJF погрешность_NOUN': 17.049880405066396,
#  'липкий_ADJF лента_NOUN': 17.04453918025859,
#  'межфазный_ADJF натяжение_NOUN': 17.043767349382907,
#  'кондитерский_ADJF изделие_NOUN': 17.040172653913867,
#  'органический_ADJF фаза_NOUN': 17.031124190764793,
#  'половой_ADJF феромон_NOUN': 17.023394322618348,
#  'короткий_ADJF замыкание_NOUN': 17.018579380614366,
#  'волновой_ADJF число_NOUN': 17.017532621476352,
#  'гомолитический_ADJF разрыв_NOUN': 16.99849144467212,
#  'контактный_ADJF обмен_NOUN': 16.99358240615426,
#  'планетарный_ADJF мельница_NOUN': 16.98452830954047,
#  'начальный_ADJF этап_NOUN': 16.984520381156138,
#  'низкотемпературный_ADJF плазма_NOUN': 16.97519405391151,
#  'внутренний_ADJF стандарт_NOUN': 16.964518455149825,
#  'эквивалентный_ADJF схема_NOUN': 16.95260792493124,
#  'культуральный_ADJF жидкость_NOUN': 16.94505021856425,
#  'стандартный_ADJF раствор_NOUN': 16.93059729663429,
#  'обогатительный_ADJF фабрика_NOUN': 16.92471577568083,
#  'южный_ADJF урал_NOUN': 16.919032258296347,
#  'краткий_ADJF справочник_NOUN': 16.91647679437499,
#  'элементарный_ADJF звено_NOUN': 16.908821104246723,
#  'шестивалентный_ADJF хром_NOUN': 16.900046901463835,
#  'сывороточный_ADJF альбумин_NOUN': 16.893746186424398,
#  'кабельный_ADJF пластикат_NOUN': 16.885029974874787,
#  'характеристический_ADJF вязкость_NOUN': 16.8841062597688,
#  'нормативный_ADJF документация_NOUN': 16.882350147564473,
#  'небольшой_ADJF порция_NOUN': 16.87443837200609,
#  'бюджетный_ADJF учреждение_NOUN': 16.859825689913837,
#  'фракционный_ADJF состав_NOUN': 16.818494031644406,
#  'динамический_ADJF светорассеяние_NOUN': 16.815370842141927,
#  'незаменимый_ADJF аминокислота_NOUN': 16.800839910274217,
#  'плодовый_ADJF оболочка_NOUN': 16.800462033640784,
#  'хвойный_ADJF порода_NOUN': 16.77150301228927,
#  'данный_ADJF случай_NOUN': 16.760869938142545,
#  'советский_ADJF энциклопедия_NOUN': 16.755758094905797,
#  'ракетный_ADJF топливо_NOUN': 16.746098558787416,
#  'дисперсный_ADJF система_NOUN': 16.71412541967854,
#  'печатный_ADJF плата_NOUN': 16.71323422196575,
#  'микрокристаллический_ADJF целлюлоза_NOUN': 16.69787205662386,
#  'пшеничный_ADJF отруби_NOUN': 16.692201310387766,
#  'нефтегазовый_ADJF дело_NOUN': 16.674944214275282,
#  'верховой_ADJF торф_NOUN': 16.670759770260318,
#  'кедровый_ADJF орех_NOUN': 16.645489106621337,
#  'ключевой_ADJF слово_NOUN': 16.633827195352076,
#  'первый_ADJF порядок_NOUN': 16.6272192304241,
#  'ротационный_ADJF вискозиметр_NOUN': 16.615195758430094,
#  'молекулярный_ADJF сит_NOUN': 16.60205435609684,
#  'различный_ADJF отрасль_NOUN': 16.596079535555155,
#  'пищевой_ADJF пром_NOUN': 16.583327123725866,
#  'пожарный_ADJF опасность_NOUN': 16.577444374889225,
#  'нагревательный_ADJF столик_NOUN': 16.577282761094306,
#  'этот_ADJF соединение_NOUN': 16.574881074141512,
#  'главный_ADJF образ_NOUN': 16.57228359575401,
#  'федеральный_ADJF агентство_NOUN': 16.566181206643833,
#  'внешний_ADJF вид_NOUN': 16.559236351369716,
#  'исходный_ADJF реагент_NOUN': 16.53875385960759,
#  'молекулярный_ADJF масса_NOUN': 16.531545978651213,
#  'очистный_ADJF сооружение_NOUN': 16.52342643085397,
#  'капельный_ADJF воронка_NOUN': 16.52217246596292,
#  'связанный_ADJF плазма_NOUN': 16.51756940255075,
#  'второй_ADJF порядок_NOUN': 16.502802802692308,
#  'роторный_ADJF испаритель_NOUN': 16.48985570151384,
#  'иностранный_ADJF язык_NOUN': 16.470781160531242,
#  'порошковый_ADJF металлургия_NOUN': 16.464303181366947,
#  'картофельный_ADJF крахмал_NOUN': 16.45230056291962,
#  'индустриальный_ADJF масло_NOUN': 16.409140960741418,
#  'различный_ADJF тип_NOUN': 16.389255137141458,
#  'пламенный_ADJF фотометрия_NOUN': 16.379882082758552,
#  'естественный_ADJF наука_NOUN': 16.376508685047153,
#  'кислотный_ADJF число_NOUN': 16.36061032636324,
#  'каустический_ADJF сода_NOUN': 16.359260112884662,
#  'такой_ADJF образ_NOUN': 16.355181130577115,
#  'кислотный_ADJF сила_NOUN': 16.346437910564788,
#  'ответственный_ADJF переписка_NOUN': 16.341200013087303,
#  'изопропиловый_ADJF спирт_NOUN': 16.33908358372091,
#  'элементарный_ADJF ячейка_NOUN': 16.335111287078416,
#  'дубильный_ADJF вещество_NOUN': 16.32908480923549,
#  'поверхностный_ADJF натяжение_NOUN': 16.30730104823523,
#  'исп_ADJF мс_NOUN': 16.299588014058966,
#  'талловый_ADJF масло_NOUN': 16.292688352583717,
#  'свекловичный_ADJF стружка_NOUN': 16.26733898623585,
#  'наш_ADJF взгляд_NOUN': 16.26722494810286,
#  'хлорсеребряный_ADJF электрод_NOUN': 16.24251931892213,
#  'этот_ADJF факт_NOUN': 16.242164501389517,
#  'лесотехнический_ADJF академия_NOUN': 16.20413417466799,
#  'данный_ADJF факт_NOUN': 16.184066700749675,
#  'свекловичный_ADJF жом_NOUN': 16.177128799242837,
#  'цеолитсодержащий_ADJF порода_NOUN': 16.161947524358737,
#  'капитальный_ADJF затрата_NOUN': 16.15849994540146,
#  'сей_ADJF пора_NOUN': 16.114575666841837,
#  'статистический_ADJF обработка_NOUN': 16.111291112957165,
#  'натронный_ADJF варка_NOUN': 16.1061569286421,
#  'комплексонометрический_ADJF титрование_NOUN': 16.09296258142088,
#  'трансформаторный_ADJF масло_NOUN': 16.091487444205534,
#  'библиографический_ADJF ссылка_NOUN': 16.058482053453947,
#  'полулогарифмический_ADJF координата_NOUN': 16.055745896532216,
#  'целый_ADJF ряд_NOUN': 16.028426584570138,
#  'оксиэтилированный_ADJF изононилфенол_NOUN': 16.028282658331023,
#  'медный_ADJF купорос_NOUN': 16.014908645941762,
#  'лабораторный_ADJF практикум_NOUN': 15.988125780258136,
#  'активный_ADJF ил_NOUN': 15.985358658334894,
#  'схематический_ADJF изображение_NOUN': 15.984540263369226,
#  'байкальский_ADJF институт_NOUN': 15.983742892156911,
#  'вырожденный_ADJF разветвление_NOUN': 15.923017326933474,
#  'сельский_ADJF хозяйство_NOUN': 15.920157878865382,
#  'наш_ADJF мнение_NOUN': 15.907161917881025,
#  'талловый_ADJF пек_NOUN': 15.887719415276175,
#  'национальный_ADJF азербайджан_NOUN': 15.884486675676078,
#  'молекулярный_ADJF вес_NOUN': 15.873205312416061,
#  'конический_ADJF колба_NOUN': 15.853348227737358,
#  'интерметаллический_ADJF соединение_NOUN': 15.829514297374635,
#  'силанольный_ADJF группа_NOUN': 15.825450968797341,
#  'авторский_ADJF свидетельство_NOUN': 15.823333806383395,
#  'экспериментальный_ADJF часть_NOUN': 15.81037928226249,
#  'один_ADJF сторона_NOUN': 15.785252764887797,
#  'большой_ADJF число_NOUN': 15.769260552324027,
#  'бентонитовый_ADJF глина_NOUN': 15.758681306304695,
#  'синдиотактический_ADJF полибутадиен_NOUN': 15.75779629227511,
#  'эмоциональный_ADJF выгорание_NOUN': 15.72908616026165,
#  'сосновый_ADJF живица_NOUN': 15.720117472009951,
#  'пунктирный_ADJF линия_NOUN': 15.698464956545148,
#  'входящий_ADJF состав_NOUN': 15.689186062781452,
#  'метоксильный_ADJF группа_NOUN': 15.684137137685818,
#  'сиреневый_ADJF альдегид_NOUN': 15.68222401378976,
#  'когерентный_ADJF рассеяние_NOUN': 15.681238474198128,
#  'красноярский_ADJF край_NOUN': 15.6563136243218,
#  'карбамидоформальдегидный_ADJF смола_NOUN': 15.631076423596165,
#  'головной_ADJF мозг_NOUN': 15.616368022233218,
#  'моторный_ADJF масло_NOUN': 15.615390563334664,
#  'глюкопиранозный_ADJF кольцо_NOUN': 15.61044342075286,
#  'наш_ADJF случай_NOUN': 15.606282376247167,
#  'кротоновый_ADJF альдегид_NOUN': 15.56351381464187,
#  'моторный_ADJF топливо_NOUN': 15.507835571362683,
#  'опухолевый_ADJF клетка_NOUN': 15.5022308532867,
#  'алюминиевый_ADJF гранат_NOUN': 15.498057040631647,
#  'электротермический_ADJF атомизация_NOUN': 15.429005755523265,
#  'микродуговой_ADJF оксидирование_NOUN': 15.428410135274284,
#  'хромоникелевый_ADJF сталь_NOUN': 15.42567818591613,
#  'сахарный_ADJF пром_NOUN': 15.424478381564615,
#  'последний_ADJF время_NOUN': 15.404574792160583,
#  'международный_ADJF конгресс_NOUN': 15.376190060669856,
#  'коллективный_ADJF пользование_NOUN': 15.347965645211062,
#  'батохромный_ADJF сдвиг_NOUN': 15.345729854191502,
#  'каменный_ADJF уголь_NOUN': 15.31839856211727,
#  'дальний_ADJF восток_NOUN': 15.286460750363931,
#  'тот_ADJF кафедра_NOUN': 15.258721151218342,
#  'злокачественный_ADJF опухоль_NOUN': 15.226774104381265,
#  'отличительный_ADJF особенность_NOUN': 15.224751347678557,
#  'нитритный_ADJF перегруппировка_NOUN': 15.181106957068668,
#  'стероидный_ADJF гормон_NOUN': 15.17841593248413,
#  ...}

# %%
desc_colls = {i: c_dict[i] for i in sorted(c_dict, key=c_dict.get, reverse=False)}
desc_colls
# Out:
# {'ациламинопроизводный_ADJF арилоксиантрахинон_NOUN': 2.3457526452641906,
#  'редакционный_ADJF коллегия_NOUN': 2.4688549140622427,
#  'борнокислый_ADJF аиилинуксуонай_NOUN': 2.5306406580025156,
#  'метоксибензилиденамин_ADJF метилвалерианов_NOUN': 2.541294557633888,
#  'себряковский_ADJF филиал_NOUN': 2.626221187795479,
#  'ревматический_ADJF лихорадка_NOUN': 2.6322965303179875,
#  'полихромный_ADJF расцветка_NOUN': 2.670950189525924,
#  'остромысленский_ADJF жоба_NOUN': 2.698192845490106,
#  'чутливый_ADJF елемент_NOUN': 2.700681833091412,
#  'монохромный_ADJF расцветка_NOUN': 2.7344799666885,
#  'севастопольский_ADJF бухта_NOUN': 2.9443958720934464,
#  'асбестоцементный_ADJF шифер_NOUN': 2.9521406385342224,
#  'щековый_ADJF дробилка_NOUN': 2.9753626484445768,
#  'кедринский_ADJF дмитренко_NOUN': 3.1658550441324533,
#  'роговой_ADJF обманка_NOUN': 3.1818859150846657,
#  'метилнитроамин_ADJF тринитропиридин_NOUN': 3.186039960006879,
#  'упсв_ADJF пашня_NOUN': 3.208998855146158,
#  'аскадский_ADJF кондращенко_NOUN': 3.261260410191016,
#  'метанитрофениламин_ADJF динитробензофурокс_NOUN': 3.2890862220984047,
#  'иртышский_ADJF пойма_NOUN': 3.291828554820185,
#  'латунированный_ADJF металлокорд_NOUN': 3.371835572619124,
#  'эндемический_ADJF зоб_NOUN': 3.435423383887487,
#  'древесностружечный_ADJF плита_NOUN': 3.4969329407189207,
#  'рогатый_ADJF скот_NOUN': 3.5174954286088296,
#  'гейровский_ADJF кут_NOUN': 3.6248182971617715,
#  'биотопливный_ADJF элемент_NOUN': 3.666031328901907,
#  'трехфтористый_ADJF бор_NOUN': 3.92085883140739,
#  'медоносный_ADJF пчела_NOUN': 3.9273789540143005,
#  'дифтерийный_ADJF анатоксин_NOUN': 3.9803934611319023,
#  'муаровый_ADJF узор_NOUN': 3.9884199691696636,
#  'ариламинзамещенный_ADJF тииран_NOUN': 4.003628011946299,
#  'перистальтический_ADJF насос_NOUN': 4.029460351683934,
#  'нефтеполимерный_ADJF смола_NOUN': 4.091238988753738,
#  'синегнойный_ADJF палочка_NOUN': 4.1100658929064835,
#  'типографский_ADJF краска_NOUN': 4.12553532653194,
#  'коутецкий_ADJF левич_NOUN': 4.160953784729502,
#  'нейронный_ADJF сеть_NOUN': 4.163394911608336,
#  'ползуновский_ADJF вестник_NOUN': 4.174158389403839,
#  'римский_ADJF империя_NOUN': 4.190299487867227,
#  'царский_ADJF водка_NOUN': 4.264301368251418,
#  'стресовый_ADJF чинник_NOUN': 4.302485341009474,
#  'красный_ADJF знамя_NOUN': 4.326735572254244,
#  'наноэлектронный_ADJF трансдьюсера_NOUN': 4.489864124924086,
#  'двугранный_ADJF угол_NOUN': 4.498650366557585,
#  'фоторезистный_ADJF маска_NOUN': 4.50117471129326,
#  'азовский_ADJF море_NOUN': 4.5186558324991735,
#  'заколонный_ADJF переток_NOUN': 4.584299202550966,
#  'гендерный_ADJF ландшафт_NOUN': 4.621105044374238,
#  'бутлеровский_ADJF сообщение_NOUN': 4.713803347687081,
#  'амилоидный_ADJF фибрилла_NOUN': 4.73222007917311,
#  'шубный_ADJF овчина_NOUN': 4.881795630774695,
#  'тимирязевский_ADJF проезд_NOUN': 4.990751479591569,
#  'аммонийсодержащий_ADJF фторокомплекс_NOUN': 5.010973365771079,
#  'касторовый_ADJF масло_NOUN': 5.029353862587467,
#  'поджелудочный_ADJF железа_NOUN': 5.09378310750124,
#  'термолизный_ADJF дефекат_NOUN': 5.14617204563081,
#  'бирский_ADJF филиал_NOUN': 5.150496089053358,
#  'гидроксокий_ADJF плексова_NOUN': 5.159458007551208,
#  'хронический_ADJF остеомиелит_NOUN': 5.201321958414854,
#  'двудольный_ADJF сорняк_NOUN': 5.411378138004205,
#  'биодизельный_ADJF топливо_NOUN': 5.414115089134989,
#  'подводный_ADJF лодка_NOUN': 5.467662391408707,
#  'фоторецепторный_ADJF дегенерация_NOUN': 5.50073007471838,
#  'барзасский_ADJF сапромиксит_NOUN': 5.5286807602055505,
#  'волосяной_ADJF покров_NOUN': 5.561725051656777,
#  'порядковый_ADJF номер_NOUN': 5.572792223489641,
#  'древесноволокнистый_ADJF плита_NOUN': 5.586042155578312,
#  'татарский_ADJF кристаллооптика_NOUN': 5.620318892873345,
#  'инвертный_ADJF сахар_NOUN': 5.657977617943192,
#  'трикотажный_ADJF полотно_NOUN': 5.732046895654057,
#  'наждачный_ADJF бумага_NOUN': 5.802250731327999,
#  'должностной_ADJF оклад_NOUN': 5.844126648446557,
#  'хлоркальциевый_ADJF трубка_NOUN': 5.850931908640095,
#  'таганрогский_ADJF залив_NOUN': 5.857906158769187,
#  'щитовидный_ADJF железа_NOUN': 5.902778177193133,
#  'круговой_ADJF дихроизм_NOUN': 5.994874196154041,
#  'энциклопедический_ADJF словарь_NOUN': 6.012052543211404,
#  'красивый_ADJF меч_NOUN': 6.083081952257682,
#  'книжный_ADJF полка_NOUN': 6.084498371841426,
#  'каспийский_ADJF море_NOUN': 6.11647935473688,
#  'картонный_ADJF коробка_NOUN': 6.272341195573283,
#  'пьезокварцевый_ADJF микровзвешивание_NOUN': 6.290679241411438,
#  'верхний_ADJF обод_NOUN': 6.304796018797801,
#  'агатовый_ADJF ступка_NOUN': 6.3186142448825375,
#  'энциклопедический_ADJF справочник_NOUN': 6.319488820573875,
#  'нижний_ADJF обод_NOUN': 6.359631846882044,
#  'ковариантный_ADJF символ_NOUN': 6.410122595744947,
#  'экзаменационный_ADJF билет_NOUN': 6.449989560090653,
#  'перитонеальный_ADJF макрофаг_NOUN': 6.465927168046557,
#  'поливиниловый_ADJF спирт_NOUN': 6.468698590746867,
#  'бездымный_ADJF копчение_NOUN': 6.523907263771703,
#  'высокосернистый_ADJF углеотход_NOUN': 6.540979821235352,
#  'железомарганцевый_ADJF конкреция_NOUN': 6.570124447638138,
#  'стружечный_ADJF плита_NOUN': 6.58248284169232,
#  'вечерский_ADJF конопелько_NOUN': 6.684892723117393,
#  'рыжий_ADJF ручей_NOUN': 6.749321278269515,
#  'туалетный_ADJF мыло_NOUN': 6.786471682364839,
#  'кукурузный_ADJF початок_NOUN': 6.964420377027982,
#  'кольский_ADJF полуостров_NOUN': 7.0048497361222015,
#  'менделеевский_ADJF съезд_NOUN': 7.016112320954353,
#  'машин_ADJF авиастроение_NOUN': 7.0696574326824715,
#  'тепловой_ADJF разгон_NOUN': 7.14264787534089,
#  'фотодинамический_ADJF терапия_NOUN': 7.199659993834359,
#  'плесневый_ADJF гриб_NOUN': 7.260100897448334,
#  'атактический_ADJF полипропилен_NOUN': 7.329089456176707,
#  'черноплодный_ADJF рябина_NOUN': 7.355126015398004,
#  'адресный_ADJF доставка_NOUN': 7.369718833916823,
#  'факультативный_ADJF анаэроб_NOUN': 7.463229651359793,
#  'электронный_ADJF почта_NOUN': 7.501290368251251,
#  'псевдопервый_ADJF порядок_NOUN': 7.502552530082514,
#  'гуморальный_ADJF иммунитет_NOUN': 7.5700226090279585,
#  'поваренный_ADJF соль_NOUN': 7.6012467307076514,
#  'куриный_ADJF помета_NOUN': 7.66787651131975,
#  'керамзитовый_ADJF гравий_NOUN': 7.6997326765888,
#  'аликвотный_ADJF часть_NOUN': 7.736483131327425,
#  'движущий_ADJF сила_NOUN': 7.779735212661927,
#  'фотоэлектронный_ADJF умножитель_NOUN': 7.84192484402226,
#  'опиоидный_ADJF рецептор_NOUN': 7.865185201690142,
#  'послеуборочный_ADJF дозревание_NOUN': 7.901256469211862,
#  'глутаровый_ADJF альдегид_NOUN': 7.920708008261822,
#  'муфельный_ADJF печь_NOUN': 7.949331950089093,
#  'круглодонный_ADJF колба_NOUN': 7.976083679166471,
#  'весь_ADJF видимость_NOUN': 7.990580688183131,
#  'унитарный_ADJF предприятие_NOUN': 8.061975185033551,
#  'стероидный_ADJF эстроген_NOUN': 8.075931146670252,
#  'желудочный_ADJF сок_NOUN': 8.120945855672472,
#  'обратный_ADJF осмос_NOUN': 8.179132403641495,
#  'трифторуксусный_ADJF кислота_NOUN': 8.249541329460301,
#  'обслуживающий_ADJF персонал_NOUN': 8.301040709447488,
#  'мутновский_ADJF геоэс_NOUN': 8.317681984513255,
#  'ленинский_ADJF проспа_NOUN': 8.326412457554301,
#  'холинэстеразный_ADJF биосенсор_NOUN': 8.33051210048865,
#  'коронарный_ADJF артерия_NOUN': 8.352843532758657,
#  'межструктурный_ADJF расстояние_NOUN': 8.394057300636739,
#  'едкий_ADJF кали_NOUN': 8.47437612378854,
#  'хлористый_ADJF тионил_NOUN': 8.500582593940823,
#  'меховой_ADJF овчина_NOUN': 8.57081500624981,
#  'трехгорлый_ADJF колба_NOUN': 8.580982024895153,
#  'едкий_ADJF натр_NOUN': 8.598800267894973,
#  'левданский_ADJF полежаев_NOUN': 8.665003079280526,
#  'самопишущий_ADJF потенциометр_NOUN': 8.687785019098913,
#  'искренний_ADJF признательность_NOUN': 8.728354899193512,
#  'учебный_ADJF заведение_NOUN': 8.745656682322444,
#  'неспаренный_ADJF электрон_NOUN': 8.776164805232238,
#  'решетчатый_ADJF надрез_NOUN': 8.808990215050896,
#  'коронный_ADJF разряд_NOUN': 8.857676562602407,
#  'делительный_ADJF воронка_NOUN': 9.001481364761846,
#  'бронзовый_ADJF медаль_NOUN': 9.134013582159362,
#  'снежный_ADJF покров_NOUN': 9.154036005930134,
#  'нагнетательный_ADJF скважина_NOUN': 9.190268769975559,
#  'кембриджский_ADJF банк_NOUN': 9.235754586823413,
#  'персональный_ADJF компьютер_NOUN': 9.297435034941472,
#  'теломерный_ADJF повтор_NOUN': 9.307892218084568,
#  'первомайский_ADJF сыктывкар_NOUN': 9.352549940768089,
#  'мраморный_ADJF кальцит_NOUN': 9.418027592815651,
#  'питтинговый_ADJF коррозия_NOUN': 9.428181648515777,
#  'усталостный_ADJF выносливость_NOUN': 9.460244346870722,
#  'посадочный_ADJF площадка_NOUN': 9.465402421201018,
#  'акционерный_ADJF общество_NOUN': 9.548011438710772,
#  'суперионный_ADJF проводник_NOUN': 9.574838180605758,
#  'водонефтяной_ADJF эмульсия_NOUN': 9.594820194527347,
#  'магнетронный_ADJF распыление_NOUN': 9.628951150244003,
#  'магнетронный_ADJF напыление_NOUN': 9.661612167586071,
#  'альдольный_ADJF конденсация_NOUN': 9.693242098910034,
#  'приморский_ADJF край_NOUN': 9.697419494712644,
#  'творожный_ADJF сыворотка_NOUN': 9.7121015656402,
#  'пристальный_ADJF внимание_NOUN': 9.836046716684185,
#  'пероксильный_ADJF радикал_NOUN': 9.87606001308687,
#  'сахарный_ADJF диабет_NOUN': 9.919515122853843,
#  'октябрьский_ADJF революция_NOUN': 10.043272982590628,
#  'золотистый_ADJF стафилококк_NOUN': 10.10029377498749,
#  'диэтиловый_ADJF эфир_NOUN': 10.231732478829178,
#  'пиромеллитовый_ADJF диангидрид_NOUN': 10.258849890512483,
#  'пьезокварцевый_ADJF резонатор_NOUN': 10.306558982828314,
#  'пивной_ADJF сусло_NOUN': 10.313332525973568,
#  'перманганатный_ADJF окисляемость_NOUN': 10.32382035765791,
#  'диметиловый_ADJF эфир_NOUN': 10.33751459202472,
#  'слизистый_ADJF оболочка_NOUN': 10.376795486965102,
#  'отбельный_ADJF земля_NOUN': 10.405687690341654,
#  'нуклеиновый_ADJF кислота_NOUN': 10.451893087002702,
#  'почечный_ADJF камень_NOUN': 10.453673440599795,
#  'куйбышевский_ADJF водохранилище_NOUN': 10.455331129343595,
#  'лурий_ADJF ю_NOUN': 10.472533450357485,
#  'листовой_ADJF опада_NOUN': 10.538093182436063,
#  'газотурбинный_ADJF двигатель_NOUN': 10.658369617322196,
#  'водоносный_ADJF горизонт_NOUN': 10.732147503550298,
#  'поволжский_ADJF регион_NOUN': 10.773136744770698,
#  'кожный_ADJF покров_NOUN': 11.03585381882963,
#  'токовый_ADJF выплеск_NOUN': 11.07679397419163,
#  'плазмонный_ADJF резонанс_NOUN': 11.10251404481557,
#  'противопожарный_ADJF служба_NOUN': 11.124470373940722,
#  'надземный_ADJF часть_NOUN': 11.133763311294443,
#  'предэкспоненциальный_ADJF множитель_NOUN': 11.15511229498013,
#  'гипсохромный_ADJF сдвиг_NOUN': 11.182895709349102,
#  'неприятный_ADJF запах_NOUN': 11.185622387942791,
#  'вакуумный_ADJF газойль_NOUN': 11.185958271558663,
#  'служебный_ADJF телефон_NOUN': 11.203777407954284,
#  'северный_ADJF каспий_NOUN': 11.205336620667637,
#  'бромистый_ADJF циан_NOUN': 11.238990348658966,
#  'метилотрофный_ADJF дрожжи_NOUN': 11.25880931907648,
#  'камчатский_ADJF краб_NOUN': 11.410332057179277,
#  'изоамиловый_ADJF спирт_NOUN': 11.439382747114639,
#  'докторский_ADJF диссертация_NOUN': 11.441899560316745,
#  'кальцинированный_ADJF сода_NOUN': 11.44468225338235,
#  'российский_ADJF федерация_NOUN': 11.453248427139723,
#  'древесный_ADJF зелень_NOUN': 11.489580586198125,
#  'алмазоподобный_ADJF полупроводник_NOUN': 11.490298499990962,
#  'карбоксилатный_ADJF фосфабетаин_NOUN': 11.509488770958662,
#  'местный_ADJF самоуправление_NOUN': 11.516056107315434,
#  'формульный_ADJF единица_NOUN': 11.600474311619731,
#  'аналитический_ADJF бюллетень_NOUN': 11.605145676303522,
#  'цинковый_ADJF белила_NOUN': 11.662986667777103,
#  'трубчатый_ADJF ультрафильтр_NOUN': 11.686864656250203,
#  'серебряный_ADJF наночернила_NOUN': 11.694896429640808,
#  'университетский_ADJF наб_NOUN': 11.695890339374136,
#  'пентагональный_ADJF бипирамида_NOUN': 11.75023994972992,
#  'дорожный_ADJF разметка_NOUN': 11.780324821767083,
#  'ударопрочный_ADJF полистирол_NOUN': 11.793899922761767,
#  'петролейный_ADJF эфир_NOUN': 11.79635082803132,
#  'капитальный_ADJF вложение_NOUN': 11.808546098865293,
#  'нобелевский_ADJF премия_NOUN': 11.858317159527097,
#  'броуновский_ADJF движение_NOUN': 11.867298030328767,
#  'корковый_ADJF пробка_NOUN': 11.924688991672383,
#  'ленинский_ADJF проспект_NOUN': 12.013993367830858,
#  'государственный_ADJF контракт_NOUN': 12.071727674875289,
#  'ортофосфорный_ADJF кислота_NOUN': 12.07174079234264,
#  'алкогольный_ADJF интоксикация_NOUN': 12.074701701206115,
#  'вазелиновый_ADJF масло_NOUN': 12.075412430273559,
#  'широкополосный_ADJF развязка_NOUN': 12.103306387948173,
#  'ленинский_ADJF гора_NOUN': 12.169118845650855,
#  'апатитовый_ADJF концентрат_NOUN': 12.18248209543758,
#  'светоизлучающий_ADJF диод_NOUN': 12.234540473576299,
#  'библиографический_ADJF список_NOUN': 12.366225558894453,
#  'магистральный_ADJF газопровод_NOUN': 12.381693590765018,
#  'надосадочный_ADJF жидкость_NOUN': 12.384005532373015,
#  'межплоскостной_ADJF расстояние_NOUN': 12.38723475501435,
#  'полевой_ADJF шпат_NOUN': 12.388865096116422,
#  'малоновый_ADJF диальдегид_NOUN': 12.436841023183424,
#  'пр_ADJF ленин_NOUN': 12.45140280012425,
#  'ярославский_ADJF шоссе_NOUN': 12.59941259071949,
#  'мицелиальный_ADJF гриб_NOUN': 12.621281952918425,
#  'изомолярный_ADJF серия_NOUN': 12.632313078788265,
#  'панкреатический_ADJF липаза_NOUN': 12.673564679098284,
#  'ртутный_ADJF порометрия_NOUN': 12.693240755087263,
#  'дикарбоновый_ADJF кислота_NOUN': 12.718252485637622,
#  'злокачественный_ADJF новообразование_NOUN': 12.75212723909026,
#  'последний_ADJF год_NOUN': 12.805472163030887,
#  'сахарный_ADJF тростник_NOUN': 12.80742306402649,
#  'агрегатный_ADJF состояние_NOUN': 12.853081469511746,
#  'безалкогольный_ADJF напиток_NOUN': 12.857952524597362,
#  'бензиловый_ADJF спирт_NOUN': 12.890842111966466,
#  'полулогарифмический_ADJF анаморфоз_NOUN': 12.902763328325078,
#  'феноксильный_ADJF радикал_NOUN': 12.954433551338067,
#  'кандидатский_ADJF диссертация_NOUN': 13.015278370943342,
#  'ботанический_ADJF сад_NOUN': 13.025820689643448,
#  'доверительный_ADJF вероятность_NOUN': 13.0513862092158,
#  'нижний_ADJF новгород_NOUN': 13.057128413522756,
#  'англ_ADJF ред_NOUN': 13.072653015159336,
#  'доверительный_ADJF интервал_NOUN': 13.09581493345148,
#  'сегодняшний_ADJF день_NOUN': 13.098598820462575,
#  'несимметричный_ADJF диметилгидразин_NOUN': 13.16778494142041,
#  'ташкентский_ADJF химико_NOUN': 13.17042031459164,
#  'лазерный_ADJF абляция_NOUN': 13.182651794003482,
#  'волоконный_ADJF световод_NOUN': 13.194305619632193,
#  'торсионный_ADJF угол_NOUN': 13.20541379833422,
#  'следовой_ADJF количество_NOUN': 13.220806893747708,
#  'онкологический_ADJF заболевание_NOUN': 13.24530463119466,
#  'нижегородский_ADJF госуниверситет_NOUN': 13.26371226522592,
#  'кишечный_ADJF тракт_NOUN': 13.305125376912983,
#  'октановый_ADJF число_NOUN': 13.428771992684295,
#  'издательский_ADJF дом_NOUN': 13.434938715231548,
#  'первый_ADJF очередь_NOUN': 13.508053587748096,
#  'малоугловой_ADJF рассеяние_NOUN': 13.51692073227093,
#  'волгоградский_ADJF госуд_NOUN': 13.55040855463773,
#  'крахмальный_ADJF клейстер_NOUN': 13.568100818322305,
#  'гидростатический_ADJF взвешивание_NOUN': 13.601240234103825,
#  'генеральный_ADJF директор_NOUN': 13.649961011082425,
#  'фотоэлектронный_ADJF спектроскопия_NOUN': 13.654405213936382,
#  'кишечный_ADJF палочка_NOUN': 13.686899431250367,
#  'конечный_ADJF итог_NOUN': 13.7360257511058,
#  'плазмообразующий_ADJF газ_NOUN': 13.82957761409319,
#  'карбамидный_ADJF пенопласт_NOUN': 13.876628807084957,
#  'цеолитовый_ADJF туф_NOUN': 13.88915143113631,
#  'непосредственный_ADJF близость_NOUN': 13.937799812071468,
#  'лиофильный_ADJF сушка_NOUN': 14.050853159721873,
#  'травянистый_ADJF растение_NOUN': 14.062565655356096,
#  'последний_ADJF десятилетие_NOUN': 14.066551387583802,
#  'казанский_ADJF технол_NOUN': 14.131804794700946,
#  'пр_ADJF октябрь_NOUN': 14.13430843191468,
#  'изобутиловый_ADJF спирт_NOUN': 14.135115863338436,
#  'гомологический_ADJF ряд_NOUN': 14.176805541879967,
#  'рентгеновский_ADJF дифрактометрия_NOUN': 14.230509768385458,
#  'сварной_ADJF шов_NOUN': 14.23490775045688,
#  'йодный_ADJF число_NOUN': 14.245299433290253,
#  'маточный_ADJF раствор_NOUN': 14.2457182742272,
#  'дочерний_ADJF изотоп_NOUN': 14.272704242064798,
#  'злаковый_ADJF культура_NOUN': 14.312374060105272,
#  'комбинационный_ADJF рассеяние_NOUN': 14.329962388467557,
#  'пилотный_ADJF установка_NOUN': 14.366092012381088,
#  'краснодарский_ADJF край_NOUN': 14.375263287072023,
#  'восточный_ADJF забайкалье_NOUN': 14.411032656054608,
#  'пр_ADJF гр_NOUN': 14.418844252266524,
#  'прямогонный_ADJF бензин_NOUN': 14.419503278737064,
#  'монтмориллонитовый_ADJF глина_NOUN': 14.577972122698077,
#  'полупроницаемый_ADJF мембрана_NOUN': 14.61488253471373,
#  'кинематический_ADJF вязкость_NOUN': 14.656695399799387,
#  'составной_ADJF часть_NOUN': 14.662895025056764,
#  'отличительный_ADJF черта_NOUN': 14.684688539351841,
#  'рапсовый_ADJF масло_NOUN': 14.701572456470611,
#  'земной_ADJF кора_NOUN': 14.704643445254304,
#  'аккумуляторный_ADJF батарея_NOUN': 14.71943014936205,
#  'первичный_ADJF акт_NOUN': 14.738743115526516,
#  'латунный_ADJF вентиль_NOUN': 14.756335009016524,
#  'оренбургский_ADJF гос_NOUN': 14.759557053101087,
#  'таможенный_ADJF союз_NOUN': 14.794994469981647,
#  'правовой_ADJF сознание_NOUN': 14.803971640323173,
#  'четыреххлористый_ADJF углерод_NOUN': 14.823134282890225,
#  'политехнический_ADJF институт_NOUN': 14.857349550317254,
#  'крайний_ADJF мера_NOUN': 14.883031617274007,
#  'аварийный_ADJF разлив_NOUN': 14.902093785295147,
#  'каолиновый_ADJF глина_NOUN': 14.904390359947799,
#  'налоговый_ADJF преступление_NOUN': 14.927402320699873,
#  'критический_ADJF нода_NOUN': 14.95363115321211,
#  'аскорбиновый_ADJF кислота_NOUN': 15.00078173809061,
#  'агрегативный_ADJF устойчивость_NOUN': 15.000785178836987,
#  'аппаратурный_ADJF оформление_NOUN': 15.051675203087646,
#  'ротационный_ADJF испаритель_NOUN': 15.055096670836669,
#  'костный_ADJF регенерат_NOUN': 15.071452638835924,
#  'накопительный_ADJF культура_NOUN': 15.090812098638363,
#  'плавиковый_ADJF кислота_NOUN': 15.12120743864881,
#  'политехнический_ADJF университет_NOUN': 15.124939810697875,
#  'нитроксильный_ADJF радикал_NOUN': 15.143585304457275,
#  'вулканизационный_ADJF сетка_NOUN': 15.156284008305486,
#  'стероидный_ADJF гормон_NOUN': 15.17841593248413,
#  'нитритный_ADJF перегруппировка_NOUN': 15.181106957068668,
#  'отличительный_ADJF особенность_NOUN': 15.224751347678557,
#  'злокачественный_ADJF опухоль_NOUN': 15.226774104381265,
#  'тот_ADJF кафедра_NOUN': 15.258721151218342,
#  'дальний_ADJF восток_NOUN': 15.286460750363931,
#  'каменный_ADJF уголь_NOUN': 15.31839856211727,
#  'батохромный_ADJF сдвиг_NOUN': 15.345729854191502,
#  'коллективный_ADJF пользование_NOUN': 15.347965645211062,
#  'международный_ADJF конгресс_NOUN': 15.376190060669856,
#  'последний_ADJF время_NOUN': 15.404574792160583,
#  'сахарный_ADJF пром_NOUN': 15.424478381564615,
#  'хромоникелевый_ADJF сталь_NOUN': 15.42567818591613,
#  'микродуговой_ADJF оксидирование_NOUN': 15.428410135274284,
#  'электротермический_ADJF атомизация_NOUN': 15.429005755523265,
#  'алюминиевый_ADJF гранат_NOUN': 15.498057040631647,
#  'опухолевый_ADJF клетка_NOUN': 15.5022308532867,
#  'моторный_ADJF топливо_NOUN': 15.507835571362683,
#  'кротоновый_ADJF альдегид_NOUN': 15.56351381464187,
#  'наш_ADJF случай_NOUN': 15.606282376247167,
#  'глюкопиранозный_ADJF кольцо_NOUN': 15.61044342075286,
#  'моторный_ADJF масло_NOUN': 15.615390563334664,
#  'головной_ADJF мозг_NOUN': 15.616368022233218,
#  'карбамидоформальдегидный_ADJF смола_NOUN': 15.631076423596165,
#  'красноярский_ADJF край_NOUN': 15.6563136243218,
#  'когерентный_ADJF рассеяние_NOUN': 15.681238474198128,
#  'сиреневый_ADJF альдегид_NOUN': 15.68222401378976,
#  'метоксильный_ADJF группа_NOUN': 15.684137137685818,
#  'входящий_ADJF состав_NOUN': 15.689186062781452,
#  'пунктирный_ADJF линия_NOUN': 15.698464956545148,
#  'сосновый_ADJF живица_NOUN': 15.720117472009951,
#  'эмоциональный_ADJF выгорание_NOUN': 15.72908616026165,
#  'синдиотактический_ADJF полибутадиен_NOUN': 15.75779629227511,
#  'бентонитовый_ADJF глина_NOUN': 15.758681306304695,
#  'большой_ADJF число_NOUN': 15.769260552324027,
#  'один_ADJF сторона_NOUN': 15.785252764887797,
#  'экспериментальный_ADJF часть_NOUN': 15.81037928226249,
#  'авторский_ADJF свидетельство_NOUN': 15.823333806383395,
#  'силанольный_ADJF группа_NOUN': 15.825450968797341,
#  'интерметаллический_ADJF соединение_NOUN': 15.829514297374635,
#  'конический_ADJF колба_NOUN': 15.853348227737358,
#  'молекулярный_ADJF вес_NOUN': 15.873205312416061,
#  'национальный_ADJF азербайджан_NOUN': 15.884486675676078,
#  'талловый_ADJF пек_NOUN': 15.887719415276175,
#  'наш_ADJF мнение_NOUN': 15.907161917881025,
#  'сельский_ADJF хозяйство_NOUN': 15.920157878865382,
#  'вырожденный_ADJF разветвление_NOUN': 15.923017326933474,
#  'байкальский_ADJF институт_NOUN': 15.983742892156911,
#  'схематический_ADJF изображение_NOUN': 15.984540263369226,
#  'активный_ADJF ил_NOUN': 15.985358658334894,
#  'лабораторный_ADJF практикум_NOUN': 15.988125780258136,
#  'медный_ADJF купорос_NOUN': 16.014908645941762,
#  'оксиэтилированный_ADJF изононилфенол_NOUN': 16.028282658331023,
#  'целый_ADJF ряд_NOUN': 16.028426584570138,
#  'полулогарифмический_ADJF координата_NOUN': 16.055745896532216,
#  'библиографический_ADJF ссылка_NOUN': 16.058482053453947,
#  'трансформаторный_ADJF масло_NOUN': 16.091487444205534,
#  'комплексонометрический_ADJF титрование_NOUN': 16.09296258142088,
#  'натронный_ADJF варка_NOUN': 16.1061569286421,
#  'статистический_ADJF обработка_NOUN': 16.111291112957165,
#  'сей_ADJF пора_NOUN': 16.114575666841837,
#  'капитальный_ADJF затрата_NOUN': 16.15849994540146,
#  'цеолитсодержащий_ADJF порода_NOUN': 16.161947524358737,
#  'свекловичный_ADJF жом_NOUN': 16.177128799242837,
#  'данный_ADJF факт_NOUN': 16.184066700749675,
#  'лесотехнический_ADJF академия_NOUN': 16.20413417466799,
#  'этот_ADJF факт_NOUN': 16.242164501389517,
#  'хлорсеребряный_ADJF электрод_NOUN': 16.24251931892213,
#  'наш_ADJF взгляд_NOUN': 16.26722494810286,
#  'свекловичный_ADJF стружка_NOUN': 16.26733898623585,
#  'талловый_ADJF масло_NOUN': 16.292688352583717,
#  'исп_ADJF мс_NOUN': 16.299588014058966,
#  'поверхностный_ADJF натяжение_NOUN': 16.30730104823523,
#  'дубильный_ADJF вещество_NOUN': 16.32908480923549,
#  'элементарный_ADJF ячейка_NOUN': 16.335111287078416,
#  'изопропиловый_ADJF спирт_NOUN': 16.33908358372091,
#  'ответственный_ADJF переписка_NOUN': 16.341200013087303,
#  'кислотный_ADJF сила_NOUN': 16.346437910564788,
#  'такой_ADJF образ_NOUN': 16.355181130577115,
#  'каустический_ADJF сода_NOUN': 16.359260112884662,
#  'кислотный_ADJF число_NOUN': 16.36061032636324,
#  'естественный_ADJF наука_NOUN': 16.376508685047153,
#  'пламенный_ADJF фотометрия_NOUN': 16.379882082758552,
#  'различный_ADJF тип_NOUN': 16.389255137141458,
#  'индустриальный_ADJF масло_NOUN': 16.409140960741418,
#  'картофельный_ADJF крахмал_NOUN': 16.45230056291962,
#  'порошковый_ADJF металлургия_NOUN': 16.464303181366947,
#  'иностранный_ADJF язык_NOUN': 16.470781160531242,
#  'роторный_ADJF испаритель_NOUN': 16.48985570151384,
#  'второй_ADJF порядок_NOUN': 16.502802802692308,
#  'связанный_ADJF плазма_NOUN': 16.51756940255075,
#  'капельный_ADJF воронка_NOUN': 16.52217246596292,
#  'очистный_ADJF сооружение_NOUN': 16.52342643085397,
#  'молекулярный_ADJF масса_NOUN': 16.531545978651213,
#  'исходный_ADJF реагент_NOUN': 16.53875385960759,
#  'внешний_ADJF вид_NOUN': 16.559236351369716,
#  'федеральный_ADJF агентство_NOUN': 16.566181206643833,
#  'главный_ADJF образ_NOUN': 16.57228359575401,
#  'этот_ADJF соединение_NOUN': 16.574881074141512,
#  'нагревательный_ADJF столик_NOUN': 16.577282761094306,
#  'пожарный_ADJF опасность_NOUN': 16.577444374889225,
#  'пищевой_ADJF пром_NOUN': 16.583327123725866,
#  'различный_ADJF отрасль_NOUN': 16.596079535555155,
#  'молекулярный_ADJF сит_NOUN': 16.60205435609684,
#  'ротационный_ADJF вискозиметр_NOUN': 16.615195758430094,
#  'первый_ADJF порядок_NOUN': 16.6272192304241,
#  'ключевой_ADJF слово_NOUN': 16.633827195352076,
#  'кедровый_ADJF орех_NOUN': 16.645489106621337,
#  'верховой_ADJF торф_NOUN': 16.670759770260318,
#  'нефтегазовый_ADJF дело_NOUN': 16.674944214275282,
#  'пшеничный_ADJF отруби_NOUN': 16.692201310387766,
#  'микрокристаллический_ADJF целлюлоза_NOUN': 16.69787205662386,
#  'печатный_ADJF плата_NOUN': 16.71323422196575,
#  'дисперсный_ADJF система_NOUN': 16.71412541967854,
#  'ракетный_ADJF топливо_NOUN': 16.746098558787416,
#  'советский_ADJF энциклопедия_NOUN': 16.755758094905797,
#  'данный_ADJF случай_NOUN': 16.760869938142545,
#  'хвойный_ADJF порода_NOUN': 16.77150301228927,
#  'плодовый_ADJF оболочка_NOUN': 16.800462033640784,
#  'незаменимый_ADJF аминокислота_NOUN': 16.800839910274217,
#  'динамический_ADJF светорассеяние_NOUN': 16.815370842141927,
#  'фракционный_ADJF состав_NOUN': 16.818494031644406,
#  'бюджетный_ADJF учреждение_NOUN': 16.859825689913837,
#  'небольшой_ADJF порция_NOUN': 16.87443837200609,
#  'нормативный_ADJF документация_NOUN': 16.882350147564473,
#  'характеристический_ADJF вязкость_NOUN': 16.8841062597688,
#  'кабельный_ADJF пластикат_NOUN': 16.885029974874787,
#  'сывороточный_ADJF альбумин_NOUN': 16.893746186424398,
#  'шестивалентный_ADJF хром_NOUN': 16.900046901463835,
#  'элементарный_ADJF звено_NOUN': 16.908821104246723,
#  'краткий_ADJF справочник_NOUN': 16.91647679437499,
#  'южный_ADJF урал_NOUN': 16.919032258296347,
#  'обогатительный_ADJF фабрика_NOUN': 16.92471577568083,
#  'стандартный_ADJF раствор_NOUN': 16.93059729663429,
#  'культуральный_ADJF жидкость_NOUN': 16.94505021856425,
#  'эквивалентный_ADJF схема_NOUN': 16.95260792493124,
#  'внутренний_ADJF стандарт_NOUN': 16.964518455149825,
#  'низкотемпературный_ADJF плазма_NOUN': 16.97519405391151,
#  'начальный_ADJF этап_NOUN': 16.984520381156138,
#  'планетарный_ADJF мельница_NOUN': 16.98452830954047,
#  'контактный_ADJF обмен_NOUN': 16.99358240615426,
#  'гомолитический_ADJF разрыв_NOUN': 16.99849144467212,
#  'волновой_ADJF число_NOUN': 17.017532621476352,
#  'короткий_ADJF замыкание_NOUN': 17.018579380614366,
#  'половой_ADJF феромон_NOUN': 17.023394322618348,
#  'органический_ADJF фаза_NOUN': 17.031124190764793,
#  'кондитерский_ADJF изделие_NOUN': 17.040172653913867,
#  'межфазный_ADJF натяжение_NOUN': 17.043767349382907,
#  'липкий_ADJF лента_NOUN': 17.04453918025859,
#  'систематический_ADJF погрешность_NOUN': 17.049880405066396,
#  'относительный_ADJF удлинение_NOUN': 17.0577060700824,
#  'первый_ADJF этап_NOUN': 17.057999546408986,
#  'исходный_ADJF вещество_NOUN': 17.059373251868003,
#  'известный_ADJF методика_NOUN': 17.0659179000442,
#  'значительный_ADJF мера_NOUN': 17.072510286793666,
#  'теоретический_ADJF основа_NOUN': 17.081854203596826,
#  'литьевой_ADJF полиуретан_NOUN': 17.09563960375512,
#  'оптический_ADJF плотность_NOUN': 17.096762754928534,
#  'газожидкостный_ADJF хроматография_NOUN': 17.097156433158844,
#  'целевой_ADJF программа_NOUN': 17.0989282686202,
#  'сложный_ADJF эфир_NOUN': 17.10318951936165,
#  'каталитический_ADJF система_NOUN': 17.104639772368646,
#  'хозяйственный_ADJF мыло_NOUN': 17.10896632915209,
#  'виноградный_ADJF выжимка_NOUN': 17.127542169855563,
#  'суммарный_ADJF содержание_NOUN': 17.132330705253054,
#  'ионообменный_ADJF смола_NOUN': 17.16203315605666,
#  'мерный_ADJF колба_NOUN': 17.18457643081467,
#  'модельный_ADJF раствор_NOUN': 17.185161988743726,
#  'принципиальный_ADJF схема_NOUN': 17.202960808382304,
#  'пожарный_ADJF безопасность_NOUN': 17.2050484043435,
#  'реакционный_ADJF среда_NOUN': 17.207433191899643,
#  'электрофоретический_ADJF подвижность_NOUN': 17.21326803685693,
#  'относительный_ADJF влажность_NOUN': 17.215934154339624,
#  'экстрактивный_ADJF вещество_NOUN': 17.216964902466042,
#  'этот_ADJF условие_NOUN': 17.22715105025178,
#  'красный_ADJF шлам_NOUN': 17.24693963263107,
#  'промышленный_ADJF масштаб_NOUN': 17.250063089241177,
#  'широкий_ADJF предел_NOUN': 17.253440728087543,
#  'благородный_ADJF металл_NOUN': 17.263169999496682,
#  'почвенный_ADJF покров_NOUN': 17.26396083596075,
#  'реакционный_ADJF центр_NOUN': 17.266645255451763,
#  'пшеничный_ADJF солома_NOUN': 17.28471625440881,
#  'тритерпеновый_ADJF гликозид_NOUN': 17.28582094028259,
#  'спиртовой_ADJF раствор_NOUN': 17.288445667936085,
#  'водопроводный_ADJF вода_NOUN': 17.294367026495987,
#  'конечный_ADJF продукт_NOUN': 17.301667913335915,
#  'кремниевый_ADJF кислота_NOUN': 17.30273672410349,
#  'свой_ADJF состав_NOUN': 17.305149789285107,
#  'условный_ADJF прочность_NOUN': 17.305599730485792,
#  'природный_ADJF газ_NOUN': 17.318143467699787,
#  'второй_ADJF стадия_NOUN': 17.320788482623275,
#  'шаровой_ADJF мельница_NOUN': 17.32508057824047,
#  'большой_ADJF количество_NOUN': 17.32705251693473,
#  'реакционный_ADJF способность_NOUN': 17.331499853909623,
#  'водный_ADJF вытяжка_NOUN': 17.347857978404292,
#  'рецепторный_ADJF элемент_NOUN': 17.355159260294442,
#  'реакционный_ADJF масса_NOUN': 17.355585838481865,
#  'широкий_ADJF интервал_NOUN': 17.35856842817032,
#  'фарфоровый_ADJF ступка_NOUN': 17.362395808826,
#  'нисходящий_ADJF ветвь_NOUN': 17.388724332414373,
#  'нефтепромысловый_ADJF оборудование_NOUN': 17.39088142225696,
#  'аналитический_ADJF химия_NOUN': 17.404480945391317,
#  'гранулометрический_ADJF состав_NOUN': 17.41591337084298,
#  'взрывной_ADJF автогидролиз_NOUN': 17.418211443590444,
#  'синергетический_ADJF эффект_NOUN': 17.423355032352195,
#  'структурный_ADJF единица_NOUN': 17.426051571335464,
#  'интегральный_ADJF интенсивность_NOUN': 17.43926449606966,
#  'первый_ADJF стадия_NOUN': 17.446669610648225,
#  'бутиловый_ADJF ксантогенат_NOUN': 17.44726880007323,
#  'дальнейший_ADJF исследование_NOUN': 17.450033045781783,
#  'синтетический_ADJF каучук_NOUN': 17.458066824609922,
#  'гидравлический_ADJF пресса_NOUN': 17.461279435876136,
#  'томский_ADJF орден_NOUN': 17.4637985341378,
#  'хромовый_ADJF дубление_NOUN': 17.48098240639338,
#  'кремнекислородный_ADJF тетраэдр_NOUN': 17.48198781135664,
#  'компонентный_ADJF состав_NOUN': 17.510744098493387,
#  'кировский_ADJF омск_NOUN': 17.514548379035727,
#  'сверхкритический_ADJF флюид_NOUN': 17.517739583376404,
#  'методический_ADJF указание_NOUN': 17.52207482161557,
#  'биохимический_ADJF физика_NOUN': 17.524645554704986,
#  'широкий_ADJF круг_NOUN': 17.53028151547353,
#  'настоящий_ADJF время_NOUN': 17.532755453446885,
#  'кристаллизационный_ADJF вода_NOUN': 17.54373293301049,
#  'массовый_ADJF доля_NOUN': 17.5464713744201,
#  'технологический_ADJF схема_NOUN': 17.550138990683195,
#  'нейтральный_ADJF среда_NOUN': 17.555023739663593,
#  'неорганический_ADJF вещество_NOUN': 17.56228344570103,
#  'зольный_ADJF микросфера_NOUN': 17.563100488073726,
#  'молибденовый_ADJF синь_NOUN': 17.564812138817885,
#  'мышечный_ADJF ткань_NOUN': 17.575373755943104,
#  'диполярный_ADJF циклоприсоединение_NOUN': 17.57709349304466,
#  'кислый_ADJF среда_NOUN': 17.578002115897167,
#  'химический_ADJF сдвиг_NOUN': 17.599791884352445,
#  'обратный_ADJF холодильник_NOUN': 17.6045691740914,
#  'элементарный_ADJF акт_NOUN': 17.605200021423382,
#  'калориметрический_ADJF бомба_NOUN': 17.609020730121006,
#  'видимый_ADJF область_NOUN': 17.610944392825008,
#  'мягкий_ADJF условие_NOUN': 17.61693160615537,
#  'активированный_ADJF уголь_NOUN': 17.618757587257758,
#  'исходный_ADJF раствор_NOUN': 17.6283297314638,
#  'основный_ADJF компонент_NOUN': 17.6287583883258,
#  'храпковский_ADJF вестник_NOUN': 17.630096010088703,
#  'различный_ADJF концентрация_NOUN': 17.63147500980377,
#  'финансовый_ADJF поддержка_NOUN': 17.63362893279502,
#  'пропионовый_ADJF кислота_NOUN': 17.63766851058275,
#  'карбоновый_ADJF кислота_NOUN': 17.648154560430076,
#  'литературный_ADJF источник_NOUN': 17.650674939456476,
#  'средний_ADJF размер_NOUN': 17.655013150043086,
#  'углеродный_ADJF скелет_NOUN': 17.667947137060796,
#  'сибирский_ADJF отделение_NOUN': 17.67396223744746,
#  'водный_ADJF фаза_NOUN': 17.68305649401641,
#  'стандартный_ADJF образец_NOUN': 17.68584692160936,
#  'следующий_ADJF образ_NOUN': 17.692125376011326,
#  'исходный_ADJF компонент_NOUN': 17.692572533388102,
#  'жидкий_ADJF стекло_NOUN': 17.69361817061632,
#  'водяной_ADJF паром_NOUN': 17.70223858292745,
#  'алюмооксидный_ADJF носитель_NOUN': 17.702881496641826,
#  'меховой_ADJF полуфабрикат_NOUN': 17.70537509990692,
#  'уральский_ADJF отделение_NOUN': 17.726827095736848,
#  'фосфатный_ADJF буфер_NOUN': 17.729761028261105,
#  'газовый_ADJF смесь_NOUN': 17.74759018337136,
#  'высокомолекулярный_ADJF соединение_NOUN': 17.749284677639245,
#  'начальный_ADJF стадия_NOUN': 17.752090222969272,
#  'лиственный_ADJF порода_NOUN': 17.75271979603439,
#  'заводский_ADJF лаборатория_NOUN': 17.75852334869323,
#  'комплексный_ADJF соединение_NOUN': 17.762737242871687,
#  'сульфатный_ADJF скипидар_NOUN': 17.76713725189977,
#  'фарфоровый_ADJF чашка_NOUN': 17.775293056454974,
#  'брутто_ADJF формула_NOUN': 17.78926359307088,
#  'термический_ADJF анализ_NOUN': 17.793541827733762,
#  'синхронный_ADJF термоанализатор_NOUN': 17.796727671797157,
#  'экологический_ADJF обстановка_NOUN': 17.80251922973183,
#  'несомненный_ADJF интерес_NOUN': 17.802672060225305,
#  'интенсивный_ADJF перемешивание_NOUN': 17.807877411418342,
#  'окружающий_ADJF среда_NOUN': 17.81733056796472,
#  'статический_ADJF условие_NOUN': 17.825257456693702,
#  'пластический_ADJF масса_NOUN': 17.83033528302946,
#  'мольный_ADJF отношение_NOUN': 17.833260791051668,
#  'цветной_ADJF металлургия_NOUN': 17.833886901004252,
#  'дисперсионный_ADJF среда_NOUN': 17.84053873552139,
#  'условный_ADJF обозначение_NOUN': 17.849285906161043,
#  'полимерный_ADJF матрица_NOUN': 17.85000023767649,
#  'насыщенный_ADJF раствор_NOUN': 17.852092384765044,
#  'органический_ADJF растворитель_NOUN': 17.853807641939117,
#  'новый_ADJF поколение_NOUN': 17.86276949334883,
#  'полимерный_ADJF цепь_NOUN': 17.86543540300054,
#  'индукционный_ADJF период_NOUN': 17.86889333089114,
#  'этиловый_ADJF спирт_NOUN': 17.875190910251728,
#  'низинный_ADJF торф_NOUN': 17.894997345811493,
#  'слабый_ADJF поле_NOUN': 17.895097610725966,
#  'небольшой_ADJF количество_NOUN': 17.90111114065506,
#  'фенольный_ADJF гидроксил_NOUN': 17.91217692749465,
#  'поглотительный_ADJF способность_NOUN': 17.9274799828893,
#  'всесоюзный_ADJF совещание_NOUN': 17.94368093645732,
#  'стандартный_ADJF отклонение_NOUN': 17.945954378724828,
#  'циклический_ADJF вольтамперометрия_NOUN': 17.947444037536794,
#  'воздушный_ADJF среда_NOUN': 17.957892544021433,
#  'координационный_ADJF число_NOUN': 17.966207336900442,
#  'волокнистый_ADJF полуфабрикат_NOUN': 17.971281539705505,
#  'элементный_ADJF состав_NOUN': 17.987743377789197,
#  'шинный_ADJF резина_NOUN': 17.99607871292896,
#  'особый_ADJF внимание_NOUN': 17.996335173612824,
#  'рабочий_ADJF частота_NOUN': 17.998136699181888,
#  'термический_ADJF стабильность_NOUN': 18.010232802988018,
#  'относительный_ADJF интенсивность_NOUN': 18.01486795888907,
#  'бурый_ADJF водоросль_NOUN': 18.01554047149202,
#  'широкий_ADJF распространение_NOUN': 18.02280765928951,
#  'реакционный_ADJF смесь_NOUN': 18.02410520254084,
#  'синий_ADJF лента_NOUN': 18.034485480801045,
#  'относительный_ADJF погрешность_NOUN': 18.04225417480387,
#  'значительный_ADJF количество_NOUN': 18.043800315514503,
#  'начальный_ADJF момент_NOUN': 18.059654243764832,
#  'линейный_ADJF участок_NOUN': 18.064853998627402,
#  'циклический_ADJF вольтамперограмма_NOUN': 18.06734579695578,
#  'катионный_ADJF полимеризация_NOUN': 18.0710807090615,
#  'окислительный_ADJF стресс_NOUN': 18.07250902572529,
#  'нитратный_ADJF группа_NOUN': 18.0736184351783,
#  'электронный_ADJF плотность_NOUN': 18.076916854567312,
#  'хлористый_ADJF метилен_NOUN': 18.08146887260128,
#  'аналитический_ADJF весы_NOUN': 18.084963865920226,
#  'российский_ADJF химико_NOUN': 18.093296456889,
#  'гетерогенный_ADJF катализ_NOUN': 18.094108838564715,
#  'сушильный_ADJF шкаф_NOUN': 18.099185357975216,
#  'относительный_ADJF ошибка_NOUN': 18.115673327019127,
#  'краевой_ADJF угол_NOUN': 18.120900364571597,
#  'гидратный_ADJF оболочка_NOUN': 18.122266398875354,
#  'графитовый_ADJF монохроматор_NOUN': 18.1273367131197,
#  'незначительный_ADJF количество_NOUN': 18.131522709928063,
#  'щелочной_ADJF среда_NOUN': 18.14152335353752,
#  'газофазный_ADJF распад_NOUN': 18.146449562737033,
#  'тепловой_ADJF расширение_NOUN': 18.152306240438726,
#  'углеродистый_ADJF сталь_NOUN': 18.171106053443864,
#  'большой_ADJF внимание_NOUN': 18.17972321840597,
#  'эластомерный_ADJF композиция_NOUN': 18.183257442642233,
#  'устойчивый_ADJF развитие_NOUN': 18.184324118904737,
#  'изоэлектрический_ADJF точка_NOUN': 18.191267591704054,
#  'костный_ADJF ткань_NOUN': 18.198269730362224,
#  'морской_ADJF вода_NOUN': 18.21489448926597,
#  'зондовый_ADJF микроскоп_NOUN': 18.21834407006342,
#  'ионный_ADJF жидкость_NOUN': 18.218553095496887,
#  'жидкофазный_ADJF окисление_NOUN': 18.226190136059287,
#  'комплексный_ADJF переработка_NOUN': 18.229178104330618,
#  'физический_ADJF смысл_NOUN': 18.22997384756214,
#  'широкий_ADJF диапазон_NOUN': 18.23560075306595,
#  'молекулярный_ADJF кислород_NOUN': 18.23723472208856,
#  'резиновый_ADJF смесь_NOUN': 18.240409183633957,
#  'среднеквадратичный_ADJF отклонение_NOUN': 18.2408281570644,
#  'западный_ADJF сибирь_NOUN': 18.257410738572005,
#  'приоритетный_ADJF направление_NOUN': 18.261258139112236,
#  'больший_ADJF часть_NOUN': 18.266122418359046,
#  'химический_ADJF состав_NOUN': 18.272075375585416,
#  'многокомпонентный_ADJF система_NOUN': 18.279398214786166,
#  'газовый_ADJF хроматография_NOUN': 18.283820331436704,
#  'термический_ADJF распад_NOUN': 18.28423058476661,
#  'диффузионный_ADJF сок_NOUN': 18.292960233598954,
#  'полезный_ADJF ископаемое_NOUN': 18.29796206836915,
#  'известковый_ADJF молоко_NOUN': 18.30110200673771,
#  'метиловый_ADJF спирт_NOUN': 18.3137776647832,
#  'кислотный_ADJF центр_NOUN': 18.315461538381978,
#  'восточный_ADJF сибирь_NOUN': 18.320536561393848,
#  'текстурный_ADJF характеристика_NOUN': 18.334392884037772,
#  'сравнительный_ADJF анализ_NOUN': 18.33789368804524,
#  'функциональный_ADJF группа_NOUN': 18.347955778920998,
#  'потенциальный_ADJF барьер_NOUN': 18.34857633283076,
#  'тепловой_ADJF эффект_NOUN': 18.353457668744944,
#  'органический_ADJF соединение_NOUN': 18.354948834795902,
#  'дальнейший_ADJF увеличение_NOUN': 18.365477981085593,
#  'этиловый_ADJF эфир_NOUN': 18.36665565371258,
#  'сплошной_ADJF линия_NOUN': 18.36703802581245,
#  'точный_ADJF навеска_NOUN': 18.36747733350492,
#  'муравьиный_ADJF кислота_NOUN': 18.370946049778958,
#  'математический_ADJF статистика_NOUN': 18.37238251154821,
#  'визуальный_ADJF наблюдение_NOUN': 18.37574606220135,
#  'валентный_ADJF угол_NOUN': 18.379326011805723,
#  'алюминиевый_ADJF фольга_NOUN': 18.382714335472556,
#  'ароматический_ADJF ядро_NOUN': 18.38969019064847,
#  'кварцевый_ADJF песок_NOUN': 18.390893676473762,
#  'фазовый_ADJF переход_NOUN': 18.391274881001756,
#  'полимерный_ADJF композиция_NOUN': 18.3969826887705,
#  'бурый_ADJF уголь_NOUN': 18.39855161066386,
#  'калиевый_ADJF соль_NOUN': 18.419037689588514,
#  'существенный_ADJF недостаток_NOUN': 18.431039598371903,
#  'постоянный_ADJF масса_NOUN': 18.435609218351356,
#  'переменный_ADJF валентность_NOUN': 18.435763757849443,
#  'стандартный_ADJF методика_NOUN': 18.438304764885995,
#  'краткий_ADJF сообщение_NOUN': 18.43932679078162,
#  'наш_ADJF страна_NOUN': 18.44476438196163,
#  'органический_ADJF синтез_NOUN': 18.449604810786226,
#  'дальнейший_ADJF повышение_NOUN': 18.459681503834062,
#  'физический_ADJF химия_NOUN': 18.465456151631493,
#  'водный_ADJF среда_NOUN': 18.4657142826663,
#  'активный_ADJF уголь_NOUN': 18.47765340150333,
#  'литературный_ADJF данные_NOUN': 18.48381232145,
#  'гликозидный_ADJF связь_NOUN': 18.48547872060254,
#  'средний_ADJF диаметр_NOUN': 18.489762627278882,
#  'следующий_ADJF схема_NOUN': 18.491978769072407,
#  'сульфатный_ADJF лигнин_NOUN': 18.520097970184967,
#  'ионный_ADJF аккумулятор_NOUN': 18.521072950685433,
#  'особый_ADJF место_NOUN': 18.546237258905883,
#  'полисульфидный_ADJF олигомер_NOUN': 18.550538740788475,
#  'электродный_ADJF процесс_NOUN': 18.56084588017251,
#  'коптильный_ADJF дым_NOUN': 18.561466748350913,
#  'донный_ADJF отложение_NOUN': 18.56566229339054,
#  'косвенный_ADJF подтверждение_NOUN': 18.566283168377005,
#  'древесный_ADJF мука_NOUN': 18.56741568752767,
#  'лабораторный_ADJF условие_NOUN': 18.58446907060214,
#  'малый_ADJF количество_NOUN': 18.585276304660084,
#  'подсолнечный_ADJF масло_NOUN': 18.590063505807446,
#  'цветной_ADJF металл_NOUN': 18.590331221044995,
#  'бинарный_ADJF смесь_NOUN': 18.599238820710337,
#  'сухой_ADJF остаток_NOUN': 18.604528754548333,
#  'аналитический_ADJF сигнал_NOUN': 18.60601677582908,
#  'сульфгидрильный_ADJF собиратель_NOUN': 18.60740521376302,
#  'концентрированный_ADJF раствор_NOUN': 18.61090500379871,
#  'переходный_ADJF состояние_NOUN': 18.61602701870253,
#  'полиэфирный_ADJF смола_NOUN': 18.619404974243484,
#  'целевой_ADJF продукт_NOUN': 18.622265511208678,
#  'красный_ADJF цвет_NOUN': 18.627090054771408,
#  'остаточный_ADJF концентрация_NOUN': 18.629007762056986,
#  'азотистый_ADJF основание_NOUN': 18.633237322736992,
#  'жидкостный_ADJF экстракция_NOUN': 18.635795000514992,
#  'динамический_ADJF вязкость_NOUN': 18.63757717965202,
#  'средний_ADJF значение_NOUN': 18.639821992121362,
#  'вибрационный_ADJF мельница_NOUN': 18.641153230239976,
#  'равномерный_ADJF распределение_NOUN': 18.646579042300854,
#  'мономолекулярный_ADJF распад_NOUN': 18.649059265068388,
#  'кажущийся_ADJF энергия_NOUN': 18.6519264145695,
#  'наружный_ADJF мисцелла_NOUN': 18.652033040430148,
#  'солянокислый_ADJF гидроксиламин_NOUN': 18.66237671389748,
#  'фазовый_ADJF превращение_NOUN': 18.662725740228286,
#  'боратный_ADJF буфер_NOUN': 18.663067464185684,
#  'электронный_ADJF удар_NOUN': 18.672970417128333,
#  'инертный_ADJF атмосфера_NOUN': 18.678181546613654,
#  'готовый_ADJF продукция_NOUN': 18.679250506294842,
#  'трехэлектродный_ADJF ячейка_NOUN': 18.682996248479974,
#  'кордиеритовый_ADJF ситалл_NOUN': 18.68630068386956,
#  'внутренний_ADJF диаметр_NOUN': 18.691473544839205,
#  'подземный_ADJF вода_NOUN': 18.69174260818563,
#  'дисперсный_ADJF фаза_NOUN': 18.70006771368887,
#  'массовый_ADJF распределение_NOUN': 18.701076944722804,
#  'полиморфный_ADJF превращение_NOUN': 18.701511407776035,
#  'потенциальный_ADJF энергия_NOUN': 18.70162536404912,
#  'практический_ADJF руководство_NOUN': 18.706482664620065,
#  'аммонийный_ADJF селитра_NOUN': 18.72017204448978,
#  'хозяйственный_ADJF деятельность_NOUN': 18.72022719606365,
#  'сырьевой_ADJF база_NOUN': 18.72397358956473,
#  'исходный_ADJF концентрация_NOUN': 18.72399353829166,
#  'виниловый_ADJF мономер_NOUN': 18.72732951161171,
#  'каменноугольный_ADJF пек_NOUN': 18.735006198307058,
#  'малеиновый_ADJF ангидрид_NOUN': 18.741139921874506,
#  'растительный_ADJF масло_NOUN': 18.741832864669068,
#  'повышенный_ADJF температура_NOUN': 18.74952666688132,
#  'диэлектрический_ADJF потеря_NOUN': 18.750307487413743,
#  'сухой_ADJF вещество_NOUN': 18.75337289402556,
#  'сельскохозяйственный_ADJF культура_NOUN': 18.756380604737064,
#  'электрический_ADJF поле_NOUN': 18.760309573934297,
#  'алюмохромовый_ADJF катализатор_NOUN': 18.76583888528491,
#  'малый_ADJF квадрат_NOUN': 18.7717884506093,
#  'борный_ADJF кислота_NOUN': 18.77279289826062,
#  'кубовый_ADJF остаток_NOUN': 18.77587635044697,
#  'пектиновый_ADJF полисахарид_NOUN': 18.783919714412466,
#  'фталевый_ADJF ангидрид_NOUN': 18.788020547111856,
#  'редкоземельный_ADJF элемент_NOUN': 18.794856264469125,
#  'термический_ADJF устойчивость_NOUN': 18.799021774414452,
#  'термический_ADJF обработка_NOUN': 18.810240304428657,
#  'нитрильный_ADJF каучук_NOUN': 18.814947145187123,
#  'пектиновый_ADJF вещество_NOUN': 18.824272511070575,
#  'жидкий_ADJF фаза_NOUN': 18.82678299709041,
#  'ароматический_ADJF нитросоединение_NOUN': 18.830577151868894,
#  'процентный_ADJF содержание_NOUN': 18.837609031051297,
#  'углеродный_ADJF наноматериал_NOUN': 18.838917056332207,
#  'тонкослойный_ADJF хроматография_NOUN': 18.83973200221319,
#  'термический_ADJF деструкция_NOUN': 18.84036435445103,
#  'переходный_ADJF металл_NOUN': 18.841263171079966,
#  'углекислый_ADJF газ_NOUN': 18.844701630391288,
#  'сольватный_ADJF оболочка_NOUN': 18.852262582326507,
#  'органический_ADJF химия_NOUN': 18.854858639655962,
#  'бутиловый_ADJF эфир_NOUN': 18.857231027603515,
#  'субстратный_ADJF специфичность_NOUN': 18.86194468962874,
#  'холостой_ADJF опыт_NOUN': 18.865741476531326,
#  'газовый_ADJF фаза_NOUN': 18.872141850162578,
#  'импедансный_ADJF спектроскопия_NOUN': 18.877156253264165,
#  'тонкий_ADJF слой_NOUN': 18.88231177239571,
#  'органический_ADJF вещество_NOUN': 18.8829484591085,
#  'катионный_ADJF полиэлектролит_NOUN': 18.883334281791363,
#  'русский_ADJF язык_NOUN': 18.887317207425827,
#  'белый_ADJF цвет_NOUN': 18.887931567463763,
#  'изотермический_ADJF выдержка_NOUN': 18.892081998048074,
#  'калийный_ADJF удобрение_NOUN': 18.892230874743202,
#  'жидкий_ADJF продукт_NOUN': 18.892804579429924,
#  'инертный_ADJF газ_NOUN': 18.901029270462104,
#  'ионный_ADJF сила_NOUN': 18.90365758673094,
#  'плазмохимический_ADJF нанотехнология_NOUN': 18.9059188917183,
#  'красящий_ADJF вещество_NOUN': 18.9061546357602,
#  'защитный_ADJF эффект_NOUN': 18.915673026727003,
#  'электронный_ADJF микроскопия_NOUN': 18.916095129700427,
#  'принципиальный_ADJF возможность_NOUN': 18.92602853944712,
#  'стеариновый_ADJF кислота_NOUN': 18.929082091354726,
#  'фенольный_ADJF соединение_NOUN': 18.938574234762168,
#  'групповой_ADJF состав_NOUN': 18.942096482947914,
#  'олеиновый_ADJF кислота_NOUN': 18.948857618866437,
#  'ацетатный_ADJF буфер_NOUN': 18.96226931635501,
#  'зубной_ADJF камень_NOUN': 18.980716448253457,
#  'учебный_ADJF пособие_NOUN': 18.998008944347415,
#  'хлористый_ADJF водород_NOUN': 18.998717903472222,
#  'щавелевый_ADJF кислота_NOUN': 19.000094893912156,
#  'научный_ADJF стать_NOUN': 19.00384499738423,
#  'калибровочный_ADJF график_NOUN': 19.004287917550116,
#  'дифракционный_ADJF картина_NOUN': 19.005736400935458,
#  'химический_ADJF превращение_NOUN': 19.01441139709353,
#  'бутиловый_ADJF спирт_NOUN': 19.02370369773206,
#  'протонный_ADJF проводимость_NOUN': 19.02681251724132,
#  'салициловый_ADJF кислота_NOUN': 19.032253456758397,
#  'метиловый_ADJF эфир_NOUN': 19.042613070422334,
#  'авиационный_ADJF материал_NOUN': 19.048435951132387,
#  'горючий_ADJF ископаемое_NOUN': 19.05481000122875,
#  'практический_ADJF конференция_NOUN': 19.05734978154577,
#  'природный_ADJF цеолит_NOUN': 19.05851737477958,
#  'жидкостный_ADJF хроматография_NOUN': 19.06064707275613,
#  'активный_ADJF компонент_NOUN': 19.06106940243208,
#  'топливный_ADJF элемент_NOUN': 19.062482027479366,
#  'плотный_ADJF упаковка_NOUN': 19.067569475981294,
#  'янтарный_ADJF кислота_NOUN': 19.068387337423022,
#  'аминокислотный_ADJF остаток_NOUN': 19.07764298087939,
#  'химический_ADJF наука_NOUN': 19.085120037152606,
#  'научный_ADJF труд_NOUN': 19.087177835002876,
#  'свободный_ADJF радикал_NOUN': 19.09125877976927,
#  'ведущий_ADJF инженер_NOUN': 19.094106820854282,
#  'колоночный_ADJF хроматография_NOUN': 19.09561463177633,
#  'свободный_ADJF энергия_NOUN': 19.09681558359066,
#  'термический_ADJF разложение_NOUN': 19.097055589850186,
#  'двухвалентный_ADJF железо_NOUN': 19.104258858737538,
#  'электрохимический_ADJF поведение_NOUN': 19.1052015468511,
#  'предельный_ADJF ток_NOUN': 19.105790011447624,
#  'клеточный_ADJF стенка_NOUN': 19.113462300671014,
#  'гидравлический_ADJF сопротивление_NOUN': 19.131963927145968,
#  'электрохимический_ADJF ячейка_NOUN': 19.1421316521236,
#  'структурный_ADJF формула_NOUN': 19.150153395125304,
#  'неподвижный_ADJF фаза_NOUN': 19.150869086006622,
#  'натриевый_ADJF соль_NOUN': 19.154297490753436,
#  'технический_ADJF наука_NOUN': 19.15835893414879,
#  'электрический_ADJF взрыв_NOUN': 19.17304500436792,
#  'паровой_ADJF фаза_NOUN': 19.176414238058662,
#  'температурный_ADJF интервал_NOUN': 19.178371806020785,
#  'двойной_ADJF связь_NOUN': 19.180513212128393,
#  'методический_ADJF семинар_NOUN': 19.18269224515896,
#  'квантовый_ADJF выход_NOUN': 19.183488236008518,
#  'пластовый_ADJF вода_NOUN': 19.19218700513682,
#  'гуминовый_ADJF кислота_NOUN': 19.19305909382446,
#  'педагогический_ADJF кадр_NOUN': 19.19419748136646,
#  'эпоксидный_ADJF смола_NOUN': 19.196457625842264,
#  'спектральный_ADJF характеристика_NOUN': 19.201174903502686,
#  'элементный_ADJF анализ_NOUN': 19.201427575931085,
#  'эфирный_ADJF масло_NOUN': 19.202290197642604,
#  'калибровочный_ADJF графика_NOUN': 19.20976107908948,
#  'рисовый_ADJF шелуха_NOUN': 19.22010868354843,
#  'щелочной_ADJF металл_NOUN': 19.220727915371832,
#  'промежуточный_ADJF продукт_NOUN': 19.224138422887226,
#  'стехиометрический_ADJF соотношение_NOUN': 19.22586674176476,
#  'активный_ADJF вещество_NOUN': 19.232713004947513,
#  'химический_ADJF анализ_NOUN': 19.233703778538064,
#  'мольный_ADJF доля_NOUN': 19.248373561936603,
#  'экспериментальный_ADJF значение_NOUN': 19.24904411267171,
#  'полимерный_ADJF материал_NOUN': 19.257428989042374,
#  'химический_ADJF реакция_NOUN': 19.263249248543104,
#  'большой_ADJF интерес_NOUN': 19.27159167362464,
#  'экстремальный_ADJF характер_NOUN': 19.27248862180368,
#  'стехиометрический_ADJF коэффициент_NOUN': 19.27608693079879,
#  'цинковый_ADJF пыль_NOUN': 19.276400252074826,
#  'значительный_ADJF степень_NOUN': 19.286783984889766,
#  'поровый_ADJF пространство_NOUN': 19.287834478229453,
#  'экспериментальный_ADJF данные_NOUN': 19.2888113684032,
#  'полный_ADJF удаление_NOUN': 19.293916298912357,
#  'алифатический_ADJF спирт_NOUN': 19.297005498238768,
#  'межатомный_ADJF расстояние_NOUN': 19.297322947216948,
#  'платиновый_ADJF тигль_NOUN': 19.298312416350775,
#  'апротонный_ADJF растворитель_NOUN': 19.301315723109283,
#  'изоморфный_ADJF замещение_NOUN': 19.30346052853937,
#  'вспомогательный_ADJF электрод_NOUN': 19.31324980892749,
#  'углеродный_ADJF волокно_NOUN': 19.325726432338694,
#  'токовый_ADJF нагрузка_NOUN': 19.32917426206797,
#  'больший_ADJF количество_NOUN': 19.334639761934657,
#  'углеродный_ADJF нанотрубка_NOUN': 19.335226621261913,
#  'фильтровальный_ADJF бумага_NOUN': 19.335672939543468,
#  'отрицательный_ADJF значение_NOUN': 19.342354239413627,
#  'подвижный_ADJF фаза_NOUN': 19.343048917226575,
#  'ферментный_ADJF препарат_NOUN': 19.346938310723917,
#  'молочный_ADJF сыворотка_NOUN': 19.348426754280364,
#  'гидролизный_ADJF лигнин_NOUN': 19.355659646507508,
#  'химический_ADJF метод_NOUN': 19.358851226587046,
#  'угловой_ADJF коэффициент_NOUN': 19.36088155645578,
#  'аммиачный_ADJF селитра_NOUN': 19.363256370043263,
#  'нижний_ADJF граница_NOUN': 19.363452974742426,
#  'удельный_ADJF электропроводность_NOUN': 19.36459351133367,
#  'длительный_ADJF хранение_NOUN': 19.368549283095557,
#  'углеводородный_ADJF радикал_NOUN': 19.369235334445733,
#  'тройной_ADJF система_NOUN': 19.372132531885487,
#  'пассивный_ADJF состояние_NOUN': 19.37542901442147,
#  'рентгеновский_ADJF луч_NOUN': 19.375686527534267,
#  'сульфидный_ADJF минерал_NOUN': 19.3801806726383,
#  'приповерхностный_ADJF слой_NOUN': 19.383224277398707,
#  'щелочной_ADJF раствор_NOUN': 19.390164502293104,
#  'электронный_ADJF ресурс_NOUN': 19.395146206059664,
#  'коллоидный_ADJF химия_NOUN': 19.41006341024878,
#  'соляный_ADJF кислота_NOUN': 19.425397609658017,
#  'пищевой_ADJF продукт_NOUN': 19.426474155960396,
#  'бромистый_ADJF аллил_NOUN': 19.427465578490494,
#  'базисный_ADJF набор_NOUN': 19.42877685193608,
#  'каталитический_ADJF свойство_NOUN': 19.429441365068524,
#  'микроскопический_ADJF снимок_NOUN': 19.43005165769359,
#  'низкий_ADJF концентрация_NOUN': 19.44326610329248,
#  'нержавеющий_ADJF сталь_NOUN': 19.448170596428753,
#  'ртутный_ADJF капля_NOUN': 19.45963315554061,
#  'диффузионный_ADJF ограничение_NOUN': 19.46051480618083,
#  'гуминовый_ADJF вещество_NOUN': 19.46133854909904,
#  'стальной_ADJF мембрана_NOUN': 19.464523001830983,
#  'неорганический_ADJF химия_NOUN': 19.465930194263034,
#  'винный_ADJF кислота_NOUN': 19.471479718732496,
#  'водный_ADJF раствор_NOUN': 19.47148237820528,
#  'магнитный_ADJF резонанс_NOUN': 19.475768423688713,
#  'жидкостный_ADJF хроматограф_NOUN': 19.478157369934035,
#  'цементный_ADJF камень_NOUN': 19.479796742381396,
#  'азотный_ADJF кислота_NOUN': 19.480289736285215,
#  'дизельный_ADJF топливо_NOUN': 19.48126167481255,
#  'третичный_ADJF амин_NOUN': 19.488462064822837,
#  'коричневый_ADJF цвет_NOUN': 19.490258306042605,
#  'марганцевый_ADJF руда_NOUN': 19.491790684926617,
#  'фосфорнокислый_ADJF катионит_NOUN': 19.500241453989076,
#  'взаимный_ADJF расположение_NOUN': 19.50030113682446,
#  'серный_ADJF кислота_NOUN': 19.504033916705154,
#  'ионизационный_ADJF детектор_NOUN': 19.518619455018577,
#  'каталитический_ADJF активность_NOUN': 19.522843607324315,
#  'центральный_ADJF атом_NOUN': 19.525241498346492,
#  'электрокинетический_ADJF потенциал_NOUN': 19.526656328413043,
#  'ртутный_ADJF лампа_NOUN': 19.537959190634034,
#  'адсорбционный_ADJF слой_NOUN': 19.53937550615223,
#  'ионный_ADJF обмен_NOUN': 19.553503134178325,
#  'биологический_ADJF активность_NOUN': 19.56110534223817,
#  'предварительный_ADJF обработка_NOUN': 19.563017901126916,
#  'адсорбционный_ADJF способность_NOUN': 19.56437631320329,
#  'ферментативный_ADJF гидролиз_NOUN': 19.566884962416662,
#  'отрицательный_ADJF заряд_NOUN': 19.57227338897147,
#  'палладиевый_ADJF катализатор_NOUN': 19.58567855195853,
#  'атмосферный_ADJF давление_NOUN': 19.591918098126406,
#  'численный_ADJF значение_NOUN': 19.60082209143373,
#  'комнатный_ADJF температура_NOUN': 19.60545541810163,
#  'кинетический_ADJF параметр_NOUN': 19.607205027313938,
#  'широкий_ADJF применение_NOUN': 19.621595932950868,
#  'лимонный_ADJF кислота_NOUN': 19.638767334760615,
#  'растительный_ADJF происхождение_NOUN': 19.64342515057766,
#  'положительный_ADJF заряд_NOUN': 19.64553423194774,
#  'дифференциальный_ADJF уравнение_NOUN': 19.64848528871877,
#  'технологический_ADJF университет_NOUN': 19.660665911208145,
#  'стеклоуглеродный_ADJF электрод_NOUN': 19.667025649822662,
#  'низкий_ADJF температура_NOUN': 19.673586556982535,
#  'нулевой_ADJF заряд_NOUN': 19.677052497248706,
#  'количественный_ADJF оценка_NOUN': 19.68565748590636,
#  'жирный_ADJF кислота_NOUN': 19.690308952357697,
#  'аммониевый_ADJF соль_NOUN': 19.694164601502358,
#  'российский_ADJF фонд_NOUN': 19.696900382658022,
#  'трехвалентный_ADJF железо_NOUN': 19.708253384948645,
#  'сравнительный_ADJF оценка_NOUN': 19.70832460385866,
#  'межслоевой_ADJF пространство_NOUN': 19.70847512990188,
#  'кинетический_ADJF закономерность_NOUN': 19.720691758958054,
#  'термодинамический_ADJF функция_NOUN': 19.721789479740703,
#  'рентгеноспектральный_ADJF микроанализ_NOUN': 19.728503255851415,
#  'технический_ADJF университет_NOUN': 19.741466427914666,
#  ...}
